# %%
import json
import pandas as pd
from tqdm.notebook import tqdm
import re

# %%
def show(x):
    print(x.shape)
    return x.head()

# %%
with open("../data_raw/science_parse_output.json") as file:
    lines = [json.loads(l) for l in tqdm(file.readlines())]
len(lines)
# Out:
#   0%|          | 0/1365 [00:00<?, ?it/s]
# 1365

# %%
lines[0]
# Out:
# {'name': '/home/jarobyte/Zotero/storage/FJGSUPN6/GCR-Powerpoint-Webinar-Jan-2020.pdf',
#  'metadata': {'source': 'CRF',
#   'title': None,
#   'authors': ['Mimi McClure',
#    'Laura Regassa',
#    'Mike Roco',
#    'Nora Savage',
#    'Steven Breckler',
#    'Toby Parcel'],
#   'emails': ['gcrelig@nsf.gov.'],
#   'sections': [{'heading': None,
#     'text': 'NSF Big Idea: Growing Convergence Research\nNSF Big Idea: Growing Convergence Research\nWebinar Objectives\n• Overview of the program & program goals • Solicitation specifics • Review criteria • Q/A\nSubmit questions via the Q/A panel in Zoom or via email to gcrelig@nsf.gov.\nNSF Big Idea: Growing Convergence Research\nConvergence at NSF\n• Convergence is a multifaceted concept • It has long history at NSF; part of NSF’s portfolio since 1954 • It is currently an important component of several parts of NSF’s\nportfolio, including • the 6 research-oriented Big Ideas • NSF Convergence Accelerator • Growing Convergence Research (GCR) a process-oriented Big Idea\nNSF Big Idea: Growing Convergence Research'},
#    {'heading': 'Characteristics of Convergence Research', 'text': ''},
#    {'heading': 'Supported by GCR',
#     'text': '• Research driven by a specific and compelling problem. Convergence Research is generally inspired by the need to address a specific challenge or opportunity, whether it arises from deep scientific questions or pressing societal needs.\n• Deep integration across disciplines. As experts from different disciplines pursue common research challenges, their knowledge, theories, methods, data, research communities and languages become increasingly intermingled or integrated. New frameworks, paradigms or even disciplines can form sustained interactions across multiple communities.\nNSF Big Idea: Growing Convergence Research'},
#    {'heading': 'Stewardship of the GCR',
#     'text': '• Lead NSF organization: Office of Integrative Activities\n• Solicitation and proposal review : NSF wide Working Group:\n• Award oversight: Directorates\nNSF Big Idea: Growing Convergence Research\nBig Idea: Growing Convergence Research (GCR)\nFoundation-wide Working Group comprised of:\nBIO: Michell Elekonich CISE: Mimi McClure EHR: Laura Regassa ENG: Mike Roco, Nora Savage GEO: Sarah Ruth MPS: Leonard Spinu OIA: Dragana Brzakovic (chair), Leah Nichols OISE: Jessica Robin SBE: Steven Breckler, Toby Parcel\nNSF Big Idea: Growing Convergence Research'},
#    {'heading': 'GCR solicitation NSF 19-551',
#     'text': '• Deadline: February 3, 2020\n• Project duration: 5 years, divided into two phases: Phase 1: Years 1-2 and Phase 2: Years 3-5.\n• Budget: total up to 3.6M • Years 1-2, up to 600k/year • Years 3-5 Successful teams will receive funding up to 800k/year (progress of\neach team will be determined at the end of year 2 via a reverse site visit)\nNSF Big Idea: Growing Convergence Research'},
#    {'heading': 'Who may submit',
#     'text': '• Institutions of Higher Education\n• Non-profit, non-academic organizations\nNSF Big Idea: Growing Convergence Research'},
#    {'heading': 'Who may serve as a PI',
#     'text': '• The PIs must hold full-time appointments in research or teaching positions at US-based campuses/offices of eligible organizations.\n• A PI or a co-PI may participate in only one proposal in response to this solicitation.\nNSF Big Idea: Growing Convergence Research'},
#    {'heading': 'What does GCR support?',
#     'text': 'Project characteristics: • Basic research ideas that require convergence • Projects that are inspired by a scientific or societal grand challenge • Topics that are not currently supported by NSF’S existing programs and initiatives • Projects with potential for sustainability beyond award duration\nTeam characteristics: • Small research teams deliberately comprised of members with diverse\nscientific/technical backgrounds • Collectively working to develop effective ways of communicating across\ndisciplines and sectors and developing sustainable relationships\nNSF Big Idea: Growing Convergence Research'},
#    {'heading': 'Proposal Structure',
#     'text': '• Vision driving the proposed research • Appropriateness for this solicitation • Research Plan: Written for five years, divided into 2 phases (years 1-2\nand years 3-5) • Supplementary Documents:\n• List of Project Personnel • Convergence Management Plan • Letters of Collaboration\nNSF Big Idea: Growing Convergence Research'},
#    {'heading': 'GCR Review Criteria',
#     'text': '• The Intellectual Merit criterion encompasses the potential to advance knowledge; and\n• The Broader Impacts criterion encompasses the potential to benefit society and contribute to the achievement of specific, desired societal outcomes.\n• Program Specific\nNSF Big Idea: Growing Convergence Research'},
#    {'heading': 'Program Specific Review Criteria',
#     'text': '• Is the vision motivating this proposal sufficiently compelling and ambitious to justify\ninvestment in developing a convergent research community? Is there potential to sustain convergence research beyond this project?\n• Is the proposed research appropriate for this solicitation? Do the proposed ideas differ markedly from research supported by other NSF programs, initiatives, Big Ideas or other NSF funding mechanisms? • Are the intended approaches to address the scientific and/or technological questions innovative, promising, and appropriate for growing convergence research? • Is the proposed management plan appropriate to foster convergent team-formation and sustainability? • Are the goals outlined for the two research plan phases ambitious enough to move the science toward addressing the problem that engendered the proposal? • Is the assembled team of partner organizations and personnel appropriate and essential for the planned project? Are the partner organizations and participants meaningfully integrated?\nNSF Big Idea: Growing Convergence Research\nThank you!\nQuestions\nEmail questions to gcrelig@nsf.gov.\nFollow up with your panel managers if you have questions later.\nNSF Big Idea: Growing Convergence Research'},
#    {'heading': 'Cultivation of Convergence', 'text': 'Research at NSF'}],
#   'references': [],
#   'referenceMentions': [],
#   'year': 2020,
#   'abstractText': None,
#   'creator': 'Acrobat PDFMaker 19 for PowerPoint'}}

# %%
raw = pd.DataFrame(lines)\
.assign(title = lambda df: df.metadata.map(lambda x: x["title"]),
        abstract = lambda df: df.metadata.map(lambda x: x["abstractText"]),
        sections = lambda df: df.metadata.map(lambda x: x["sections"]),
        references = lambda df: df.metadata.map(lambda x: x["references"]),
        citations = lambda df: df.metadata.map(lambda x: x["referenceMentions"]),
)\

show(raw)
# Out:
# (1365, 7)
#                                                 name  \
# 0  /home/jarobyte/Zotero/storage/FJGSUPN6/GCR-Pow...
# 1  /home/jarobyte/Zotero/storage/E47J4XWS/Beineke...
# 2  /home/jarobyte/Zotero/storage/K9SMVNFH/IDST at...
# 3  /home/jarobyte/Zotero/storage/FEFDDM7K/Kirsch ...
# 4  /home/jarobyte/Zotero/storage/GXE9CYPA/acl13-S...
#
#                                             metadata  \
# 0  {'source': 'CRF', 'title': None, 'authors': ['...
# 1  {'source': 'CRF', 'title': 'Characterizations ...
# 2  {'source': 'META', 'title': 'IDST at TREC 2019...
# 3  {'source': 'CRF', 'title': 'BatchBALD: Efficie...
# 4  {'source': 'META', 'title': 'A Sentence Compre...
#
#                                                title  \
# 0                                               None
# 1                Characterizations of Derived Graphs
# 2  IDST at TREC 2019 Deep Learning Track: Deep Ca...
# 3  BatchBALD: Efficient and Diverse Batch Acquisi...
# 4  A Sentence Compression Based Framework to Quer...
#
#                                             abstract  \
# 0                                               None
# 1  The derived graph of a graph G has the edges o...
# 2  This paper describes our participation in the ...
# 3  We develop BatchBALD, a tractable approximatio...
# 4  We consider the problem of using sentence comp...
#
#                                             sections  \
# 0  [{'heading': None, 'text': 'NSF Big Idea: Grow...
# 1                                               None
# 2  [{'heading': None, 'text': 'KEYWORDS cascade r...
# 3  [{'heading': '1 Introduction', 'text': 'A key ...
# 4  [{'heading': None, 'text': 'Proceedings of the...
#
#                                           references  \
# 0                                                 []
# 1  [{'title': 'On the Uniqueness of the Triangula...
# 2  [{'title': 'Overview of the TREC 2019 deep lea...
# 3  [{'title': 'Toward the next generation of reco...
# 4  [{'title': 'Syntax directed translations and t...
#
#                                            citations
# 0                                                 []
# 1  [{'referenceID': 0, 'context': 'JOURNAL OF COM...
# 2  [{'referenceID': 1, 'context': 'Our approach i...
# 3  [{'referenceID': 6, 'context': 'Active learnin...
# 4  [{'referenceID': 18, 'context': 'specific or n...

# %%
raw_na = raw.where(raw.applymap(lambda x: x is not None and x != []))
show(raw_na)
# Out:
# (1365, 7)
#                                                 name  \
# 0  /home/jarobyte/Zotero/storage/FJGSUPN6/GCR-Pow...
# 1  /home/jarobyte/Zotero/storage/E47J4XWS/Beineke...
# 2  /home/jarobyte/Zotero/storage/K9SMVNFH/IDST at...
# 3  /home/jarobyte/Zotero/storage/FEFDDM7K/Kirsch ...
# 4  /home/jarobyte/Zotero/storage/GXE9CYPA/acl13-S...
#
#                                             metadata  \
# 0  {'source': 'CRF', 'title': None, 'authors': ['...
# 1  {'source': 'CRF', 'title': 'Characterizations ...
# 2  {'source': 'META', 'title': 'IDST at TREC 2019...
# 3  {'source': 'CRF', 'title': 'BatchBALD: Efficie...
# 4  {'source': 'META', 'title': 'A Sentence Compre...
#
#                                                title  \
# 0                                                NaN
# 1                Characterizations of Derived Graphs
# 2  IDST at TREC 2019 Deep Learning Track: Deep Ca...
# 3  BatchBALD: Efficient and Diverse Batch Acquisi...
# 4  A Sentence Compression Based Framework to Quer...
#
#                                             abstract  \
# 0                                                NaN
# 1  The derived graph of a graph G has the edges o...
# 2  This paper describes our participation in the ...
# 3  We develop BatchBALD, a tractable approximatio...
# 4  We consider the problem of using sentence comp...
#
#                                             sections  \
# 0  [{'heading': None, 'text': 'NSF Big Idea: Grow...
# 1                                                NaN
# 2  [{'heading': None, 'text': 'KEYWORDS cascade r...
# 3  [{'heading': '1 Introduction', 'text': 'A key ...
# 4  [{'heading': None, 'text': 'Proceedings of the...
#
#                                           references  \
# 0                                                NaN
# 1  [{'title': 'On the Uniqueness of the Triangula...
# 2  [{'title': 'Overview of the TREC 2019 deep lea...
# 3  [{'title': 'Toward the next generation of reco...
# 4  [{'title': 'Syntax directed translations and t...
#
#                                            citations
# 0                                                NaN
# 1  [{'referenceID': 0, 'context': 'JOURNAL OF COM...
# 2  [{'referenceID': 1, 'context': 'Our approach i...
# 3  [{'referenceID': 6, 'context': 'Active learnin...
# 4  [{'referenceID': 18, 'context': 'specific or n...

# %%
papers = raw_na[["title", "abstract", "sections"]].reset_index().rename(columns = {"index":"paper_id"})
show(papers)
# Out:
# (1365, 4)
#    paper_id                                              title  \
# 0         0                                                NaN
# 1         1                Characterizations of Derived Graphs
# 2         2  IDST at TREC 2019 Deep Learning Track: Deep Ca...
# 3         3  BatchBALD: Efficient and Diverse Batch Acquisi...
# 4         4  A Sentence Compression Based Framework to Quer...
#
#                                             abstract  \
# 0                                                NaN
# 1  The derived graph of a graph G has the edges o...
# 2  This paper describes our participation in the ...
# 3  We develop BatchBALD, a tractable approximatio...
# 4  We consider the problem of using sentence comp...
#
#                                             sections
# 0  [{'heading': None, 'text': 'NSF Big Idea: Grow...
# 1                                                NaN
# 2  [{'heading': None, 'text': 'KEYWORDS cascade r...
# 3  [{'heading': '1 Introduction', 'text': 'A key ...
# 4  [{'heading': None, 'text': 'Proceedings of the...

# %%
raw_na.citations.map(len, na_action = "ignore").sum()
# Out:
# 62988.0

# %%
citations_raw = raw_na.citations.dropna().explode()
show(citations_raw)
# Out:
# (62988,)
# 1    {'referenceID': 0, 'context': 'JOURNAL OF COMB...
# 2    {'referenceID': 1, 'context': 'Our approach is...
# 2    {'referenceID': 8, 'context': 'Different from ...
# 2    {'referenceID': 5, 'context': 'Moreover, for f...
# 2    {'referenceID': 6, 'context': 'The proposed mo...
# Name: citations, dtype: object

# %%
citations = pd.DataFrame(citations_raw.tolist())\
.assign(paper_id = citations_raw.index)\
[["paper_id", "referenceID", "context", "startOffset", "endOffset"]]\
.rename(columns = {"referenceID":"internal_reference_id", 
                   "startOffset":"start_offset", 
                   "endOffset":"end_offset"})

show(citations)
citations.head(20)
# Out:
# (62988, 5)
#     paper_id  internal_reference_id  \
# 0          1                      0
# 1          2                      1
# 2          2                      8
# 3          2                      5
# 4          2                      6
# 5          2                      6
# 6          2                      6
# 7          2                      9
# 8          2                      5
# 9          2                     10
# 10         2                      8
# 11         2                      1
# 12         2                      7
# 13         2                      3
# 14         2                     11
# 15         2                      2
# 16         2                      8
# 17         2                      4
# 18         2                      0
# 19         3                      6
#
#                                               context  start_offset  \
# 0   JOURNAL OF COMBINATORIAL THEORY 9, 129--135 (1...            36
# 1   Our approach is mainly based on the BERT langu...            56
# 2   Different from many other ranking methods whic...           216
# 3   Moreover, for full ranking subtask, we use a s...            78
# 4   The proposed model is based on the pointer-gen...            59
# 5   Following [7], we also use a soft switch to ch...            10
# 6            where pдen is a soft switch used in [7].            36
# 7   After the query generation model is trained, f...           147
# 8   The expanded passages are then indexed and we ...           100
# 9   For the BM25 search engine, we use the off-the...            85
# 10  Inspired from StructBERT [9], we first modify ...            25
# 11  BERT [2] is a self-supervised approach for pre...             5
# 12  BERT [2] is a self-supervised approach for pre...            83
# 13  Recently, some variants [4, 12] of BERT langua...            24
# 14  Recently, some variants [4, 12] of BERT langua...            24
# 15  Some others found it beneficial to modify the ...           128
# 16  Some others found it beneficial to modify the ...           128
# 17  After the new BERT language model is pre-train...            87
# 18  The details of task construction, evaluation m...           145
# 19  Active learning (AL) [7] is a powerful techniq...            21
#
#     end_offset
# 0           51
# 1           59
# 2          219
# 3           81
# 4           62
# 5           13
# 6           39
# 7          151
# 8          103
# 9           89
# 10          28
# 11           8
# 12          86
# 13          31
# 14          31
# 15         134
# 16         134
# 17          90
# 18         148
# 19          24

# %%
citations.context[2]
# Out:
# 'Different from many other ranking methods which directly finetune the original BERT model in downstream task, we modify the next sentence prediction task in BERT to a 3-class sentence classification as in StructBERT [9] and pre-train a new BERT language model from scratch.'

# %%
references = raw_na.references.explode().reset_index()\
.assign(internal_reference_id = lambda df: df.groupby("index").cumcount(),
        title = lambda df: df.references.map(lambda x: x["title"], na_action = "ignore"))\
.assign(title_join = lambda df: df.title.str.replace("[^a-zA-Z]", "").str.lower())\
.rename(columns = {"index":"paper_id"})


show(references)
# Out:
# (51090, 5)
# /tmp/ipykernel_5552/969181190.py:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   .assign(title_join = lambda df: df.title.str.replace("[^a-zA-Z]", "").str.lower())\
#    paper_id                                         references  \
# 0         0                                                NaN
# 1         1  {'title': 'On the Uniqueness of the Triangular...
# 2         1  {'title': 'On the Line Graph of the Complete B...
# 3         1  {'title': 'Demonstration nouvelle d'tme Th6or6...
# 4         1  {'title': 'The Isomorphism between Graphs and ...
#
#    internal_reference_id                                              title  \
# 0                      0                                                NaN
# 1                      0  On the Uniqueness of the Triangular Associatio...
# 2                      1  On the Line Graph of the Complete Bipartite Graph
# 3                      2  Demonstration nouvelle d'tme Th6or6me de Whitn...
# 4                      3  The Isomorphism between Graphs and Their Adjoi...
#
#                                           title_join
# 0                                                NaN
# 1    ontheuniquenessofthetriangularassociationscheme
# 2          onthelinegraphofthecompletebipartitegraph
# 3  demonstrationnouvelledtmethormedewhitneysurles...
# 4  theisomorphismbetweengraphsandtheiradjointgrap...

# %%
unique_references = references.groupby("title_join")\
.agg(["min", "count"])\
.title\
.sort_values("count", ascending = False)\
.reset_index()\
.reset_index()\
.rename(columns = {"index":"global_reference_id"})

show(unique_references)
# Out:
# (28292, 4)
#    global_reference_id                                         title_join  \
# 0                    0  distributedrepresentationsofwordsandphrasesand...
# 1                    1  bertpretrainingofdeepbidirectionaltransformers...
# 2                    2            gloveglobalvectorsforwordrepresentation
# 3                    3                              attentionisallyouneed
# 4                    4               adamamethodforstochasticoptimization
#
#                                                  min  count
# 0  Distributed Representations of Words and Phras...    192
# 1  BERT: Pre-training of Deep Bidirectional Trans...    178
# 2     GloVe : Global Vectors for Word Representation    173
# 3                          Attention Is All You Need    167
# 4         Adam: A Method for Stochastic Optimization    141

# %%
final = citations.merge(references, how = "left", on = ["paper_id", "internal_reference_id"])\
.merge(unique_references, how = "left", on = "title_join")
show(final)
# Out:
# (62988, 11)
#    paper_id  internal_reference_id  \
# 0         1                      0
# 1         2                      1
# 2         2                      8
# 3         2                      5
# 4         2                      6
#
#                                              context  start_offset  \
# 0  JOURNAL OF COMBINATORIAL THEORY 9, 129--135 (1...            36
# 1  Our approach is mainly based on the BERT langu...            56
# 2  Different from many other ranking methods whic...           216
# 3  Moreover, for full ranking subtask, we use a s...            78
# 4  The proposed model is based on the pointer-gen...            59
#
#    end_offset                                         references  \
# 0          51  {'title': 'On the Uniqueness of the Triangular...
# 1          59  {'title': 'Bert: Pre-training of deep bidirect...
# 2         219  {'title': 'StructBERT: Incorporating Language ...
# 3          81  {'title': 'The probabilistic relevance framewo...
# 4          62  {'title': 'Get to the point: Summarization wit...
#
#                                                title  \
# 0  On the Uniqueness of the Triangular Associatio...
# 1  Bert: Pre-training of deep bidirectional trans...
# 2  StructBERT: Incorporating Language Structures ...
# 3  The probabilistic relevance framework: BM25 an...
# 4  Get to the point: Summarization with pointer-g...
#
#                                           title_join  global_reference_id  \
# 0    ontheuniquenessofthetriangularassociationscheme                 8672
# 1  bertpretrainingofdeepbidirectionaltransformers...                    1
# 2  structbertincorporatinglanguagestructuresintop...                  521
# 3      theprobabilisticrelevanceframeworkbmandbeyond                  171
# 4  gettothepointsummarizationwithpointergenerator...                   27
#
#                                                  min  count
# 0  On the Uniqueness of the Triangular Associatio...      1
# 1  BERT: Pre-training of Deep Bidirectional Trans...    178
# 2  StructBERT: Incorporating Language Structures ...      9
# 3  The Probabilistic Relevance Framework: BM25 an...     17
# 4  Get To The Point: Summarization with Pointer-G...     48

# %%
final.query("global_reference_id == 27").context.head(20).tolist()
# Out:
# ['The proposed model is based on the pointer-generator model [7], which is widely used in abstractive text summarization.',
#  'Following [7], we also use a soft switch to choose between generating a word from the vocabulary or copying a word from the input sequence, and calculate the final probability distribution over the extended vocabulary as:',
#  'where pдen is a soft switch used in [7].',
#  '• PGN (See et al., 2017), is the Pointer Generator Network, an abstractive summarization system based on an encoder-decoder architecture.',
#  'Abstractive summarization methods have been under intensive study, yet they often suffer from inferior performance compared to extractive methods (Allahyari et al., 2017; Nallapati et al., 2017; See et al., 2017).',
#  'Moreover, if abstractive methods are trained on these datasets, they may not show much abstraction (See et al., 2017), because they are implicitly forced to learn structural patterns (Kedzie et al.',
#  'Most abstractive summarization methods (See et al., 2017; Li et al., 2017; Zhou et al., 2017; Liu et al., 2018; Cohan et al., 2018; Paulus et al., 2018) employ sequence-to-sequence (seq2seq) models (Sutskever et al.',
#  'It outperforms several state-of-the-art abstractive models with seq2seq architecture such as (See et al., 2017; Zhou et al., 2017; Li et al., 2017).',
#  ', 2017), pointer-generator models (See et al., 2017), self-attention networks (Liu et al.',
#  'Moreover, the performance gaps between abstractive and extractive methods are much larger in our dataset than in other datasets (See et al., 2017; Paulus et al., 2018; Cohan et al., 2018), which means too that our dataset is highly abstractive.',
#  'We followed previous studies (Cheng and Lapata, 2016; Nallapati et al., 2016, 2017; See et al., 2017; Tan and Wan, 2017) in assuming that the “story highlights” associated with each article are gold-standard abstractive summaries.',
#  'that REFRESH is superior to abstractive systems (Chen et al., 2016; Nallapati et al., 2016; See et al., 2017; Tan and Wan, 2017) which are all variants of an encoder-decoder architecture',
#  ', 2014) and abstractive summarization (See et al., 2017).',
#  'Seq2seq models are commonly used in this framework [33, 39, 44, 45].',
#  'It has also been argued that generative models trained with maximum likelihood are prone to producing repetitive summaries [See et al., 2017].',
#  'BART is trained on the CNN/Dailymail summarization dataset (See et al., 2017) and fine-tuned on the Laysumm corpus.',
#  '(Nallapati et al., 2016; Paulus et al., 2018; Li et al., 2017b; See et al., 2017; Narayan et al., 2018; Gehrmann et al., 2018), thanks to the representational power afforded by deeper architectures and the availability of large-scale datasets containing',
#  'To make short-term progress towards this goal, we focus on abstractive English text summarization, as it has a long history in the NLP community [16, 8, 54, 59, 50], and is a subjective task where we believe it is difficult to quantify summary quality without human judgments.',
#  'Finally, there has been extensive research on modifying architectures [22, 59] and pre-training procedures [70, 36, 49, 60, 53, 14] for improving summarization performance.',
#  'Multisentence summary methods include the get to the point method (summarisation with pointer-generator networks) [56], a deep reinforced model for abstractive summarization (RL) [57], generative adversarial network for abstractive text summarization [58], semantic phrase exploration (ATSDL) [30], bidirectional attention encoder-decoder and bidirectional beam search [35], key information guide network [59], text summarisation abstraction improvement [60], dual encoding for abstractive text summarisation (DEATS) [61], and abstractive document summarisation via bidirectional decoder (BiSum) [62], the text abstraction summary model based on BERT word embedding and RL [63], transformerbasedmodel for single documents neural summarisation [64], text summarisation with pretrained encoders [65], and text summarisation method based on the double attention pointer network [49].']

# %% [markdown]
# # final datasets

# %%
final_citations = final[["paper_id", "internal_reference_id", "global_reference_id", "context", "start_offset", 
                         "end_offset"]]\
.dropna()\
.assign(global_reference_id = lambda df: df.global_reference_id.map(int, na_action = "ignore"))
show(final_citations)
# Out:
# (62988, 6)
#    paper_id  internal_reference_id  global_reference_id  \
# 0         1                      0                 8672
# 1         2                      1                    1
# 2         2                      8                  521
# 3         2                      5                  171
# 4         2                      6                   27
#
#                                              context  start_offset  end_offset
# 0  JOURNAL OF COMBINATORIAL THEORY 9, 129--135 (1...            36          51
# 1  Our approach is mainly based on the BERT langu...            56          59
# 2  Different from many other ranking methods whic...           216         219
# 3  Moreover, for full ranking subtask, we use a s...            78          81
# 4  The proposed model is based on the pointer-gen...            59          62

# %%
final_papers = papers.dropna().assign(text = lambda df: df.sections.map(lambda x: " ".join([s["text"] for s in x])))
show(final_papers)
# Out:
# (1211, 5)
#    paper_id                                              title  \
# 2         2  IDST at TREC 2019 Deep Learning Track: Deep Ca...
# 3         3  BatchBALD: Efficient and Diverse Batch Acquisi...
# 4         4  A Sentence Compression Based Framework to Quer...
# 5         5  DR-BiLSTM: Dependent Reading Bidirectional LST...
# 6         6  Mental health consequences of infections by co...
#
#                                             abstract  \
# 2  This paper describes our participation in the ...
# 3  We develop BatchBALD, a tractable approximatio...
# 4  We consider the problem of using sentence comp...
# 5  We present a novel deep learning architecture ...
# 6  1The Department of Cerebrovascular Diseases, T...
#
#                                             sections  \
# 2  [{'heading': None, 'text': 'KEYWORDS cascade r...
# 3  [{'heading': '1 Introduction', 'text': 'A key ...
# 4  [{'heading': None, 'text': 'Proceedings of the...
# 5  [{'heading': '1 Introduction', 'text': 'Natura...
# 6  [{'heading': None, 'text': 'Brain and Behavior...
#
#                                                 text
# 2  KEYWORDS cascade ranking, pre-trained language...
# 3  A key problem in deep learning is data efficie...
# 4  Proceedings of the 51st Annual Meeting of the ...
# 5  Natural Language Inference (NLI; a.k.a. Recogn...
# 6  Brain and Behavior. 2020;00:e01901. | 1 of 7 h...

# %%
references_abstract = unique_references\
.merge(final_papers.assign(title_join = lambda df: df.title.str.replace("[^a-zA-Z]", "").str.lower()),
       how = "left")\
.drop(columns = "title")\
.rename(columns = {"min":"title"})\
[["global_reference_id", "title", "abstract", "title_join"]]\
.drop_duplicates()

show(references_abstract)
# Out:
# (28305, 4)
# /tmp/ipykernel_5552/484812439.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   .merge(final_papers.assign(title_join = lambda df: df.title.str.replace("[^a-zA-Z]", "").str.lower()),
#    global_reference_id                                              title  \
# 0                    0  Distributed Representations of Words and Phras...
# 1                    1  BERT: Pre-training of Deep Bidirectional Trans...
# 2                    1  BERT: Pre-training of Deep Bidirectional Trans...
# 6                    2     GloVe : Global Vectors for Word Representation
# 7                    3                          Attention Is All You Need
#
#                                             abstract  \
# 0  The recently introduced continuous Skip-gram m...
# 1  We introduce a new language representation mod...
# 2  We introduce a new language representation mod...
# 6  Recent methods for learning vector space repre...
# 7  The dominant sequence transduction models are ...
#
#                                           title_join
# 0  distributedrepresentationsofwordsandphrasesand...
# 1  bertpretrainingofdeepbidirectionaltransformers...
# 2  bertpretrainingofdeepbidirectionaltransformers...
# 6            gloveglobalvectorsforwordrepresentation
# 7                              attentionisallyouneed

# %% [markdown]
# # complete references from the arxiv dataset

# %%
titles = []
abstracts = []
with open("../data_raw/arxiv-metadata-oai-snapshot.json") as file:
    for l in tqdm(file):
        d = json.loads(l)
        titles.append(re.sub(r"[^a-zA-Z]", "",d["title"]).lower())
        abstracts.append(d["abstract"])
# Out:
# 0it [00:00, ?it/s]

# %%
arxiv = pd.DataFrame(dict(title_join = titles, abstract = abstracts))
show(arxiv)
# Out:
# (1974617, 2)
#                                           title_join  \
# 0  calculationofpromptdiphotonproductioncrosssect...
# 1              sparsitycertifyinggraphdecompositions
# 2  theevolutionoftheearthmoonsystembasedonthedark...
# 3  adeterminantofstirlingcyclenumberscountsunlabe...
# 4                 fromdyadiclambdaalphatolambdaalpha
#
#                                             abstract
# 0    A fully differential calculation in perturba...
# 1    We describe a new algorithm, the $(k,\ell)$-...
# 2    The evolution of Earth-Moon system is descri...
# 3    We show that a determinant of Stirling cycle...
# 4    In this paper we show how to compute the $\L...

# %%
full_references = references_abstract.merge(arxiv, on = "title_join", how = "left")\
.assign(abstract = lambda df: df.abstract_y.combine_first(df.abstract_x))\
.drop(columns = ["abstract_x", "title_join", "abstract_y"])\
.drop_duplicates()\

show(full_references)
full_references.head(20)
# Out:
# (28319, 3)
#     global_reference_id                                              title  \
# 0                     0  Distributed Representations of Words and Phras...
# 1                     1  BERT: Pre-training of Deep Bidirectional Trans...
# 3                     2     GloVe : Global Vectors for Word Representation
# 4                     3                          Attention Is All You Need
# 6                     4         Adam: A Method for Stochastic Optimization
# 7                     5                             Long Short-Term Memory
# 8                     6           Deep Contextualized Word Representations
# 9                     7  Efficient Estimation of Word Representations i...
# 10                    8  Neural Machine Translation By Jointly Learning...
# 11                    9       Deep Residual Learning for Image Recognition
# 12                   10                        Latent Dirichlet Allocation
# 13                   11  Distributed Representations of Sentences and D...
# 14                   12  RoBERTa: A Robustly Optimized BERT Pretraining...
# 15                   13  Recursive Deep Models for Semantic Composition...
# 16                   14  Improving Language Understanding by Generative...
# 17                   15  Sequence to Sequence Learning with Neural Netw...
# 19                   16  Language Models are Unsupervised Multitask Lea...
# 20                   17  ImageNet: A Large-Scale Hierarchical Image Dat...
# 21                   18  Convolutional Neural Networks for Sentence Cla...
# 22                   19  SQuAD: 100,000+ Questions for Machine Comprehe...
#
#                                              abstract
# 0     The recently introduced continuous Skip-gram...
# 1     We introduce a new language representation m...
# 3   Recent methods for learning vector space repre...
# 4     The dominant sequence transduction models ar...
# 6     We introduce Adam, an algorithm for first-or...
# 7                                                 NaN
# 8     We introduce a new type of deep contextualiz...
# 9     We propose two novel model architectures for...
# 10    Neural machine translation is a recently pro...
# 11    Deeper neural networks are more difficult to...
# 12                                                NaN
# 13    Many machine learning algorithms require the...
# 14    Language model pretraining has led to signif...
# 15                                                NaN
# 16  Natural language understanding comprises a wid...
# 17    Deep Neural Networks (DNNs) are powerful mod...
# 19  Natural language processing tasks, such as que...
# 20                                                NaN
# 21    We report on a series of experiments with co...
# 22    We present the Stanford Question Answering D...

# %% [markdown]
# # paper sections

# %%
paper_sections = final_papers\
.drop(columns = ["title", "text", "abstract"])\
.explode("sections")\
.assign(section_order = lambda df: df.groupby("paper_id").cumcount(),
        heading = lambda df: df.sections.map(lambda x: x["heading"]),
        text = lambda df: df.sections.map(lambda x: x["text"]))\
.drop(columns = "sections")

show(paper_sections)
# Out:
# (21329, 4)
#    paper_id  section_order                                 heading  \
# 2         2              0                                    None
# 2         2              1                          1 INTRODUCTION
# 2         2              2                          2 OUR APPROACH
# 2         2              3  2.1 Document Expansion-based Retriever
# 2         2              4                2.2 BERT-based Re-ranker
#
#                                                 text
# 2  KEYWORDS cascade ranking, pre-trained language...
# 2  The Deep Learning Track is a new track first r...
# 2  This section presents our two-stage cascade ra...
# 2  For the retriever stage, we first expand each ...
# 2  With the top-k candidate passages from retriev...

# %% [markdown]
# # writing to disk

# %%
final_citations.to_csv("../data/citations.csv", index = False)

# %%
final_papers.drop(columns = "sections").to_csv("../data/papers.csv", errors = "replace", index = False)

# %%
full_references.to_csv("../data/references.csv", index = False)

# %%
paper_sections.to_csv("../data/paper_sections.csv", index = False, errors = "replace")

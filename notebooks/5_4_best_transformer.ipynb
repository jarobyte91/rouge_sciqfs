# %%
import pandas as pd
import os
from tqdm.notebook import tqdm 
from malnis import show
import matplotlib.pyplot as plt
# plt.style.use('seaborn-whitegrid')
import seaborn as sns
sns.set(style = "whitegrid")

# %%
specter_folder = "/home/jarobyte/scratch/malnis_dataset/transformer/specter/train_logs/"
specter_files = sorted(os.listdir(specter_folder))
specter_files
# Out:
# ['13923472_1.pkl',
#  '13923472_2.pkl',
#  '13925663_1.pkl',
#  '13925663_2.pkl',
#  '13954668_1.pkl',
#  '13954668_10.pkl',
#  '13954668_11.pkl',
#  '13954668_12.pkl',
#  '13954668_2.pkl',
#  '13954668_3.pkl',
#  '13954668_4.pkl',
#  '13954668_5.pkl',
#  '13954668_6.pkl',
#  '13954668_7.pkl',
#  '13954668_8.pkl',
#  '13954668_9.pkl',
#  '14158104_1.pkl',
#  '14158104_10.pkl',
#  '14158104_2.pkl',
#  '14158104_3.pkl',
#  '14158104_4.pkl',
#  '14158104_7.pkl',
#  '14158104_8.pkl',
#  '14158104_9.pkl']

# %%
specter_data = pd.concat([pd.read_pickle(specter_folder + x).assign(name = x) for x in tqdm(specter_files)])
show(specter_data)
# Out:
#   0%|          | 0/24 [00:00<?, ?it/s]
# (40008, 12)
#    epoch  total_epochs  train_loss  dim_feedforward  attention_heads  \
# 0      1             2    0.085676              100                2
# 1      2             2    0.082387              100                2
# 0      1             2    0.085858              100                2
# 1      2             2    0.082343              100                2
# 0      1             2    0.085382              100                2
#
#    num_layers  weight_decay embeddings  dev_average_precision  dev_roc_auc  \
# 0           2           0.0    specter               0.070579     0.692495
# 1           2           0.0    specter               0.070579     0.692495
# 0           2           0.0    specter               0.071586     0.689990
# 1           2           0.0    specter               0.071586     0.689990
# 0           2           0.0    specter               0.072122     0.692105
#
#    training_minutes            name
# 0          1.166121  13923472_1.pkl
# 1          1.166121  13923472_1.pkl
# 0          1.164876  13923472_2.pkl
# 1          1.164876  13923472_2.pkl
# 0          1.158074  13925663_1.pkl

# %%
sbert_folder = "/home/jarobyte/scratch/malnis_dataset/transformer/sbert/train_logs/"
sbert_files = sorted(os.listdir(sbert_folder))
sbert_files
# Out:
# ['13930805_1.pkl',
#  '13930805_2.pkl',
#  '13932680_1.pkl',
#  '13932680_10.pkl',
#  '13932680_11.pkl',
#  '13932680_12.pkl',
#  '13932680_2.pkl',
#  '13932680_3.pkl',
#  '13932680_4.pkl',
#  '13932680_5.pkl',
#  '13932680_6.pkl',
#  '13932680_7.pkl',
#  '13932680_8.pkl',
#  '13932680_9.pkl',
#  '13949838_1.pkl',
#  '13949838_2.pkl',
#  '13955003_1.pkl',
#  '13955003_10.pkl',
#  '13955003_11.pkl',
#  '13955003_12.pkl',
#  '13955003_2.pkl',
#  '13955003_5.pkl',
#  '13955003_6.pkl',
#  '13955003_7.pkl',
#  '13955003_8.pkl',
#  '13955003_9.pkl',
#  '14158098_1.pkl',
#  '14158098_10.pkl',
#  '14158098_11.pkl',
#  '14158098_12.pkl',
#  '14158098_2.pkl',
#  '14158098_3.pkl',
#  '14158098_4.pkl',
#  '14158098_5.pkl',
#  '14158098_6.pkl',
#  '14158098_7.pkl',
#  '14158098_8.pkl',
#  '14158098_9.pkl']

# %%
sbert_data = pd.concat([pd.read_pickle(sbert_folder + x).assign(name = x) for x in tqdm(sbert_files)])
show(sbert_data)
# Out:
#   0%|          | 0/38 [00:00<?, ?it/s]
# (68008, 12)
#    epoch  total_epochs  train_loss  dim_feedforward  attention_heads  \
# 0      1             2    0.094747              100                2
# 1      2             2    0.085896              100                2
# 0      1             2    0.093049              100                2
# 1      2             2    0.085771              100                2
# 0      1          2000    0.090497              200                3
#
#    num_layers  weight_decay embeddings  dev_average_precision  dev_roc_auc  \
# 0           2           0.0      sbert               0.055992     0.636101
# 1           2           0.0      sbert               0.055992     0.636101
# 0           2           0.0      sbert               0.056448     0.638237
# 1           2           0.0      sbert               0.056448     0.638237
# 0           4           0.0      sbert               0.124057     0.638035
#
#    training_minutes            name
# 0          0.438021  13930805_1.pkl
# 1          0.438021  13930805_1.pkl
# 0          0.440001  13930805_2.pkl
# 1          0.440001  13930805_2.pkl
# 0        863.757137  13932680_1.pkl

# %%
data = pd.concat([specter_data, sbert_data])
show(data)
# Out:
# (108016, 12)
#    epoch  total_epochs  train_loss  dim_feedforward  attention_heads  \
# 0      1             2    0.085676              100                2
# 1      2             2    0.082387              100                2
# 0      1             2    0.085858              100                2
# 1      2             2    0.082343              100                2
# 0      1             2    0.085382              100                2
#
#    num_layers  weight_decay embeddings  dev_average_precision  dev_roc_auc  \
# 0           2           0.0    specter               0.070579     0.692495
# 1           2           0.0    specter               0.070579     0.692495
# 0           2           0.0    specter               0.071586     0.689990
# 1           2           0.0    specter               0.071586     0.689990
# 0           2           0.0    specter               0.072122     0.692105
#
#    training_minutes            name
# 0          1.166121  13923472_1.pkl
# 1          1.166121  13923472_1.pkl
# 0          1.164876  13923472_2.pkl
# 1          1.164876  13923472_2.pkl
# 0          1.158074  13925663_1.pkl

# %% [markdown]
# # basic stats

# %%
data.total_epochs.max()
# Out:
# 2000

# %%
# max training hours

data.groupby("embeddings").training_minutes.max() / 60
# Out:
# embeddings
# sbert      15.864464
# specter    40.277938
# Name: training_minutes, dtype: float64

# %%
data.groupby("name").embeddings.min().value_counts()
# Out:
# sbert      35
# specter    27
# Name: embeddings, dtype: int64

# %%
data.groupby("name").weight_decay.min().value_counts()
# Out:
# 0.00000    32
# 0.00010     8
# 0.00100     8
# 0.00001     8
# 0.01000     6
# Name: weight_decay, dtype: int64

# %%
data.groupby("name").min().groupby(["weight_decay", "embeddings"]).size().unstack()
# Out:
# embeddings    sbert  specter
# weight_decay
# 0.00000          13       19
# 0.00001           7        1
# 0.00010           7        1
# 0.00100           4        4
# 0.01000           4        2

# %%
# best training loss

data.groupby("name").train_loss.min().sort_values().head()
# Out:
# name
# 13954668_8.pkl    0.000535
# 13954668_6.pkl    0.000679
# 13954668_1.pkl    0.000685
# 13954668_2.pkl    0.000766
# 13954668_3.pkl    0.000807
# Name: train_loss, dtype: float64

# %%
# best roc auc

data.groupby("name").dev_roc_auc.mean().sort_values(ascending = False).head()
# Out:
# name
# 14158104_9.pkl    0.730904
# 14158104_7.pkl    0.718610
# 14158104_8.pkl    0.716143
# 14158104_2.pkl    0.714681
# 14158098_9.pkl    0.705069
# Name: dev_roc_auc, dtype: float64

# %%
# best average precision

data.groupby("name").dev_average_precision.mean().sort_values(ascending = False).head()
# Out:
# name
# 13932680_10.pkl    0.127296
# 14158098_8.pkl     0.126044
# 13932680_2.pkl     0.124683
# 13932680_5.pkl     0.124591
# 14158098_9.pkl     0.124539
# Name: dev_average_precision, dtype: float64

# %%
# best models by category

data.groupby("name").min()[["embeddings", "train_loss", "dev_average_precision", "dev_roc_auc"]]\
.sort_values(["embeddings", "dev_average_precision"], ascending = False)\
.groupby("embeddings").head(3)
# Out:
#                 embeddings  train_loss  dev_average_precision  dev_roc_auc
# name
# 14158104_4.pkl     specter    0.005708               0.122862     0.677173
# 13932680_4.pkl     specter    0.001089               0.120898     0.620666
# 13954668_7.pkl     specter    0.001030               0.120330     0.633517
# 13932680_10.pkl      sbert    0.001777               0.127296     0.649823
# 14158098_8.pkl       sbert    0.005079               0.126044     0.698681
# 13932680_2.pkl       sbert    0.002046               0.124683     0.636051

# %% [markdown]
# # the effect of weight decay

# %%
data.groupby("weight_decay").train_loss.min()
# Out:
# weight_decay
# 0.00000    0.000535
# 0.00001    0.005079
# 0.00010    0.010888
# 0.00100    0.052967
# 0.01000    0.081767
# Name: train_loss, dtype: float64

# %%
data.groupby("weight_decay").dev_roc_auc.max()
# Out:
# weight_decay
# 0.00000    0.696278
# 0.00001    0.705069
# 0.00010    0.693500
# 0.00100    0.730904
# 0.01000    0.704604
# Name: dev_roc_auc, dtype: float64

# %%
data.groupby("weight_decay").dev_average_precision.max()
# Out:
# weight_decay
# 0.00000    0.127296
# 0.00001    0.126044
# 0.00010    0.108001
# 0.00100    0.092691
# 0.01000    0.076951
# Name: dev_average_precision, dtype: float64

# %% [markdown]
# # embeddings

# %%
sns.boxplot(
    data = data.groupby("name")[["dev_roc_auc", "embeddings"]].min(),
    x = "embeddings", 
    y = "dev_roc_auc"
)
plt.xlabel("Embeddings", fontsize = "large")
plt.ylabel("ROC AUC", fontsize = "large")
plt.show()

# %%
sns.boxplot(
    data = data.groupby("name")[["dev_average_precision", "embeddings"]].min(),
    x = "embeddings", 
    y = "dev_average_precision"
)
plt.xlabel("Embeddings", fontsize = "large")
plt.ylabel("Average Precision", fontsize = "large")
plt.show()

# %% [markdown]
# # metrics

# %%
data.groupby(["dim_feedforward", "num_layers"])\
.train_loss\
.min().unstack().round(4)\
.style.background_gradient(axis = None)
# Out:
# <style type="text/css">
# #T_2cb8d_row0_col0 {
#   background-color: #f5eff6;
#   color: #000000;
# }
# #T_2cb8d_row0_col1 {
#   background-color: #dcdaeb;
#   color: #000000;
# }
# #T_2cb8d_row0_col2, #T_2cb8d_row1_col2, #T_2cb8d_row6_col2 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_2cb8d_row1_col0, #T_2cb8d_row3_col0, #T_2cb8d_row5_col0 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_2cb8d_row1_col1, #T_2cb8d_row3_col2, #T_2cb8d_row8_col2 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_2cb8d_row2_col0 {
#   background-color: #f9f2f8;
#   color: #000000;
# }
# #T_2cb8d_row2_col1, #T_2cb8d_row5_col1, #T_2cb8d_row6_col1, #T_2cb8d_row7_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_2cb8d_row2_col2, #T_2cb8d_row3_col1, #T_2cb8d_row4_col1 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_2cb8d_row4_col0 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_2cb8d_row4_col2 {
#   background-color: #2c89bd;
#   color: #f1f1f1;
# }
# #T_2cb8d_row5_col2 {
#   background-color: #e9e5f1;
#   color: #000000;
# }
# #T_2cb8d_row6_col0 {
#   background-color: #e5e1ef;
#   color: #000000;
# }
# #T_2cb8d_row7_col0, #T_2cb8d_row8_col0 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_2cb8d_row7_col2 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_2cb8d_row8_col1 {
#   background-color: #2d8abd;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_2cb8d">
#   <thead>
#     <tr>
#       <th class="index_name level0" >num_layers</th>
#       <th id="T_2cb8d_level0_col0" class="col_heading level0 col0" >2</th>
#       <th id="T_2cb8d_level0_col1" class="col_heading level0 col1" >3</th>
#       <th id="T_2cb8d_level0_col2" class="col_heading level0 col2" >4</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >dim_feedforward</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2cb8d_level0_row0" class="row_heading level0 row0" >100</th>
#       <td id="T_2cb8d_row0_col0" class="data row0 col0" >0.005900</td>
#       <td id="T_2cb8d_row0_col1" class="data row0 col1" >0.016400</td>
#       <td id="T_2cb8d_row0_col2" class="data row0 col2" >0.001000</td>
#     </tr>
#     <tr>
#       <th id="T_2cb8d_level0_row1" class="row_heading level0 row1" >150</th>
#       <td id="T_2cb8d_row1_col0" class="data row1 col0" >0.005000</td>
#       <td id="T_2cb8d_row1_col1" class="data row1 col1" >nan</td>
#       <td id="T_2cb8d_row1_col2" class="data row1 col2" >0.001000</td>
#     </tr>
#     <tr>
#       <th id="T_2cb8d_level0_row2" class="row_heading level0 row2" >200</th>
#       <td id="T_2cb8d_row2_col0" class="data row2 col0" >0.003700</td>
#       <td id="T_2cb8d_row2_col1" class="data row2 col1" >0.000800</td>
#       <td id="T_2cb8d_row2_col2" class="data row2 col2" >0.001600</td>
#     </tr>
#     <tr>
#       <th id="T_2cb8d_level0_row3" class="row_heading level0 row3" >250</th>
#       <td id="T_2cb8d_row3_col0" class="data row3 col0" >0.005100</td>
#       <td id="T_2cb8d_row3_col1" class="data row3 col1" >0.001800</td>
#       <td id="T_2cb8d_row3_col2" class="data row3 col2" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_2cb8d_level0_row4" class="row_heading level0 row4" >300</th>
#       <td id="T_2cb8d_row4_col0" class="data row4 col0" >0.081900</td>
#       <td id="T_2cb8d_row4_col1" class="data row4 col1" >0.002000</td>
#       <td id="T_2cb8d_row4_col2" class="data row4 col2" >0.053300</td>
#     </tr>
#     <tr>
#       <th id="T_2cb8d_level0_row5" class="row_heading level0 row5" >350</th>
#       <td id="T_2cb8d_row5_col0" class="data row5 col0" >0.005200</td>
#       <td id="T_2cb8d_row5_col1" class="data row5 col1" >0.000800</td>
#       <td id="T_2cb8d_row5_col2" class="data row5 col2" >0.011900</td>
#     </tr>
#     <tr>
#       <th id="T_2cb8d_level0_row6" class="row_heading level0 row6" >400</th>
#       <td id="T_2cb8d_row6_col0" class="data row6 col0" >0.013300</td>
#       <td id="T_2cb8d_row6_col1" class="data row6 col1" >0.000700</td>
#       <td id="T_2cb8d_row6_col2" class="data row6 col2" >0.001000</td>
#     </tr>
#     <tr>
#       <th id="T_2cb8d_level0_row7" class="row_heading level0 row7" >450</th>
#       <td id="T_2cb8d_row7_col0" class="data row7 col0" >0.001400</td>
#       <td id="T_2cb8d_row7_col1" class="data row7 col1" >0.000500</td>
#       <td id="T_2cb8d_row7_col2" class="data row7 col2" >0.002100</td>
#     </tr>
#     <tr>
#       <th id="T_2cb8d_level0_row8" class="row_heading level0 row8" >500</th>
#       <td id="T_2cb8d_row8_col0" class="data row8 col0" >0.001400</td>
#       <td id="T_2cb8d_row8_col1" class="data row8 col1" >0.053000</td>
#       <td id="T_2cb8d_row8_col2" class="data row8 col2" >nan</td>
#     </tr>
#   </tbody>
# </table>

# %%
data.groupby(["dim_feedforward", "num_layers"])\
.dev_roc_auc\
.max().unstack().round(4)\
.style.background_gradient(axis = None)
# Out:
# <style type="text/css">
# #T_ce47b_row0_col0 {
#   background-color: #1077b4;
#   color: #f1f1f1;
# }
# #T_ce47b_row0_col1 {
#   background-color: #6ba5cd;
#   color: #f1f1f1;
# }
# #T_ce47b_row0_col2 {
#   background-color: #0569a4;
#   color: #f1f1f1;
# }
# #T_ce47b_row1_col0 {
#   background-color: #056ba9;
#   color: #f1f1f1;
# }
# #T_ce47b_row1_col1, #T_ce47b_row3_col2, #T_ce47b_row8_col2 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_ce47b_row1_col2 {
#   background-color: #d8d7e9;
#   color: #000000;
# }
# #T_ce47b_row2_col0 {
#   background-color: #045b8e;
#   color: #f1f1f1;
# }
# #T_ce47b_row2_col1 {
#   background-color: #0771b1;
#   color: #f1f1f1;
# }
# #T_ce47b_row2_col2 {
#   background-color: #056caa;
#   color: #f1f1f1;
# }
# #T_ce47b_row3_col0 {
#   background-color: #8bb2d4;
#   color: #000000;
# }
# #T_ce47b_row3_col1 {
#   background-color: #afc1dd;
#   color: #000000;
# }
# #T_ce47b_row4_col0, #T_ce47b_row8_col1 {
#   background-color: #0872b1;
#   color: #f1f1f1;
# }
# #T_ce47b_row4_col1 {
#   background-color: #04588a;
#   color: #f1f1f1;
# }
# #T_ce47b_row4_col2 {
#   background-color: #056ba7;
#   color: #f1f1f1;
# }
# #T_ce47b_row5_col0 {
#   background-color: #0f76b3;
#   color: #f1f1f1;
# }
# #T_ce47b_row5_col1 {
#   background-color: #4c99c5;
#   color: #f1f1f1;
# }
# #T_ce47b_row5_col2 {
#   background-color: #187cb6;
#   color: #f1f1f1;
# }
# #T_ce47b_row6_col0 {
#   background-color: #056ead;
#   color: #f1f1f1;
# }
# #T_ce47b_row6_col1 {
#   background-color: #045382;
#   color: #f1f1f1;
# }
# #T_ce47b_row6_col2 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_ce47b_row7_col0 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_ce47b_row7_col1 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_ce47b_row7_col2 {
#   background-color: #2484ba;
#   color: #f1f1f1;
# }
# #T_ce47b_row8_col0 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_ce47b">
#   <thead>
#     <tr>
#       <th class="index_name level0" >num_layers</th>
#       <th id="T_ce47b_level0_col0" class="col_heading level0 col0" >2</th>
#       <th id="T_ce47b_level0_col1" class="col_heading level0 col1" >3</th>
#       <th id="T_ce47b_level0_col2" class="col_heading level0 col2" >4</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >dim_feedforward</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ce47b_level0_row0" class="row_heading level0 row0" >100</th>
#       <td id="T_ce47b_row0_col0" class="data row0 col0" >0.696300</td>
#       <td id="T_ce47b_row0_col1" class="data row0 col1" >0.670800</td>
#       <td id="T_ce47b_row0_col2" class="data row0 col2" >0.705100</td>
#     </tr>
#     <tr>
#       <th id="T_ce47b_level0_row1" class="row_heading level0 row1" >150</th>
#       <td id="T_ce47b_row1_col0" class="data row1 col0" >0.702700</td>
#       <td id="T_ce47b_row1_col1" class="data row1 col1" >nan</td>
#       <td id="T_ce47b_row1_col2" class="data row1 col2" >0.633500</td>
#     </tr>
#     <tr>
#       <th id="T_ce47b_level0_row2" class="row_heading level0 row2" >200</th>
#       <td id="T_ce47b_row2_col0" class="data row2 col0" >0.714700</td>
#       <td id="T_ce47b_row2_col1" class="data row2 col1" >0.698900</td>
#       <td id="T_ce47b_row2_col2" class="data row2 col2" >0.702300</td>
#     </tr>
#     <tr>
#       <th id="T_ce47b_level0_row3" class="row_heading level0 row3" >250</th>
#       <td id="T_ce47b_row3_col0" class="data row3 col0" >0.661600</td>
#       <td id="T_ce47b_row3_col1" class="data row3 col1" >0.649800</td>
#       <td id="T_ce47b_row3_col2" class="data row3 col2" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_ce47b_level0_row4" class="row_heading level0 row4" >300</th>
#       <td id="T_ce47b_row4_col0" class="data row4 col0" >0.698600</td>
#       <td id="T_ce47b_row4_col1" class="data row4 col1" >0.716100</td>
#       <td id="T_ce47b_row4_col2" class="data row4 col2" >0.703500</td>
#     </tr>
#     <tr>
#       <th id="T_ce47b_level0_row5" class="row_heading level0 row5" >350</th>
#       <td id="T_ce47b_row5_col0" class="data row5 col0" >0.696600</td>
#       <td id="T_ce47b_row5_col1" class="data row5 col1" >0.678800</td>
#       <td id="T_ce47b_row5_col2" class="data row5 col2" >0.693500</td>
#     </tr>
#     <tr>
#       <th id="T_ce47b_level0_row6" class="row_heading level0 row6" >400</th>
#       <td id="T_ce47b_row6_col0" class="data row6 col0" >0.701000</td>
#       <td id="T_ce47b_row6_col1" class="data row6 col1" >0.718600</td>
#       <td id="T_ce47b_row6_col2" class="data row6 col2" >0.612800</td>
#     </tr>
#     <tr>
#       <th id="T_ce47b_level0_row7" class="row_heading level0 row7" >450</th>
#       <td id="T_ce47b_row7_col0" class="data row7 col0" >0.606400</td>
#       <td id="T_ce47b_row7_col1" class="data row7 col1" >0.608800</td>
#       <td id="T_ce47b_row7_col2" class="data row7 col2" >0.689600</td>
#     </tr>
#     <tr>
#       <th id="T_ce47b_level0_row8" class="row_heading level0 row8" >500</th>
#       <td id="T_ce47b_row8_col0" class="data row8 col0" >0.730900</td>
#       <td id="T_ce47b_row8_col1" class="data row8 col1" >0.698600</td>
#       <td id="T_ce47b_row8_col2" class="data row8 col2" >nan</td>
#     </tr>
#   </tbody>
# </table>

# %%
data.groupby(["dim_feedforward", "num_layers"])\
.dev_average_precision\
.max().unstack().round(4)\
.style.background_gradient(axis = None)
# Out:
# <style type="text/css">
# #T_a71ca_row0_col0 {
#   background-color: #167bb6;
#   color: #f1f1f1;
# }
# #T_a71ca_row0_col1 {
#   background-color: #dddbec;
#   color: #000000;
# }
# #T_a71ca_row0_col2 {
#   background-color: #045a8d;
#   color: #f1f1f1;
# }
# #T_a71ca_row1_col0 {
#   background-color: #62a2cb;
#   color: #f1f1f1;
# }
# #T_a71ca_row1_col1, #T_a71ca_row3_col2, #T_a71ca_row8_col2 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_a71ca_row1_col2, #T_a71ca_row4_col1 {
#   background-color: #03466e;
#   color: #f1f1f1;
# }
# #T_a71ca_row2_col0 {
#   background-color: #69a5cc;
#   color: #f1f1f1;
# }
# #T_a71ca_row2_col1 {
#   background-color: #0c74b2;
#   color: #f1f1f1;
# }
# #T_a71ca_row2_col2 {
#   background-color: #034973;
#   color: #f1f1f1;
# }
# #T_a71ca_row3_col0 {
#   background-color: #1c7fb8;
#   color: #f1f1f1;
# }
# #T_a71ca_row3_col1 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_a71ca_row4_col0 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_a71ca_row4_col2 {
#   background-color: #ced0e6;
#   color: #000000;
# }
# #T_a71ca_row5_col0 {
#   background-color: #0a73b2;
#   color: #f1f1f1;
# }
# #T_a71ca_row5_col1 {
#   background-color: #034f7d;
#   color: #f1f1f1;
# }
# #T_a71ca_row5_col2 {
#   background-color: #60a1ca;
#   color: #f1f1f1;
# }
# #T_a71ca_row6_col0 {
#   background-color: #73a9cf;
#   color: #f1f1f1;
# }
# #T_a71ca_row6_col1 {
#   background-color: #03476f;
#   color: #f1f1f1;
# }
# #T_a71ca_row6_col2 {
#   background-color: #2a88bc;
#   color: #f1f1f1;
# }
# #T_a71ca_row7_col0 {
#   background-color: #2484ba;
#   color: #f1f1f1;
# }
# #T_a71ca_row7_col1 {
#   background-color: #046096;
#   color: #f1f1f1;
# }
# #T_a71ca_row7_col2 {
#   background-color: #046198;
#   color: #f1f1f1;
# }
# #T_a71ca_row8_col0 {
#   background-color: #023e62;
#   color: #f1f1f1;
# }
# #T_a71ca_row8_col1 {
#   background-color: #dbdaeb;
#   color: #000000;
# }
# </style>
# <table id="T_a71ca">
#   <thead>
#     <tr>
#       <th class="index_name level0" >num_layers</th>
#       <th id="T_a71ca_level0_col0" class="col_heading level0 col0" >2</th>
#       <th id="T_a71ca_level0_col1" class="col_heading level0 col1" >3</th>
#       <th id="T_a71ca_level0_col2" class="col_heading level0 col2" >4</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >dim_feedforward</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a71ca_level0_row0" class="row_heading level0 row0" >100</th>
#       <td id="T_a71ca_row0_col0" class="data row0 col0" >0.112300</td>
#       <td id="T_a71ca_row0_col1" class="data row0 col1" >0.086100</td>
#       <td id="T_a71ca_row0_col2" class="data row0 col2" >0.120900</td>
#     </tr>
#     <tr>
#       <th id="T_a71ca_level0_row1" class="row_heading level0 row1" >150</th>
#       <td id="T_a71ca_row1_col0" class="data row1 col0" >0.103600</td>
#       <td id="T_a71ca_row1_col1" class="data row1 col1" >nan</td>
#       <td id="T_a71ca_row1_col2" class="data row1 col2" >0.124600</td>
#     </tr>
#     <tr>
#       <th id="T_a71ca_level0_row2" class="row_heading level0 row2" >200</th>
#       <td id="T_a71ca_row2_col0" class="data row2 col0" >0.102900</td>
#       <td id="T_a71ca_row2_col1" class="data row2 col1" >0.113700</td>
#       <td id="T_a71ca_row2_col2" class="data row2 col2" >0.124100</td>
#     </tr>
#     <tr>
#       <th id="T_a71ca_level0_row3" class="row_heading level0 row3" >250</th>
#       <td id="T_a71ca_row3_col0" class="data row3 col0" >0.111500</td>
#       <td id="T_a71ca_row3_col1" class="data row3 col1" >0.127300</td>
#       <td id="T_a71ca_row3_col2" class="data row3 col2" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_a71ca_level0_row4" class="row_heading level0 row4" >300</th>
#       <td id="T_a71ca_row4_col0" class="data row4 col0" >0.076200</td>
#       <td id="T_a71ca_row4_col1" class="data row4 col1" >0.124700</td>
#       <td id="T_a71ca_row4_col2" class="data row4 col2" >0.089300</td>
#     </tr>
#     <tr>
#       <th id="T_a71ca_level0_row5" class="row_heading level0 row5" >350</th>
#       <td id="T_a71ca_row5_col0" class="data row5 col0" >0.113900</td>
#       <td id="T_a71ca_row5_col1" class="data row5 col1" >0.122900</td>
#       <td id="T_a71ca_row5_col2" class="data row5 col2" >0.103800</td>
#     </tr>
#     <tr>
#       <th id="T_a71ca_level0_row6" class="row_heading level0 row6" >400</th>
#       <td id="T_a71ca_row6_col0" class="data row6 col0" >0.101800</td>
#       <td id="T_a71ca_row6_col1" class="data row6 col1" >0.124500</td>
#       <td id="T_a71ca_row6_col2" class="data row6 col2" >0.109600</td>
#     </tr>
#     <tr>
#       <th id="T_a71ca_level0_row7" class="row_heading level0 row7" >450</th>
#       <td id="T_a71ca_row7_col0" class="data row7 col0" >0.110400</td>
#       <td id="T_a71ca_row7_col1" class="data row7 col1" >0.119200</td>
#       <td id="T_a71ca_row7_col2" class="data row7 col2" >0.118800</td>
#     </tr>
#     <tr>
#       <th id="T_a71ca_level0_row8" class="row_heading level0 row8" >500</th>
#       <td id="T_a71ca_row8_col0" class="data row8 col0" >0.126000</td>
#       <td id="T_a71ca_row8_col1" class="data row8 col1" >0.086500</td>
#       <td id="T_a71ca_row8_col2" class="data row8 col2" >nan</td>
#     </tr>
#   </tbody>
# </table>

# %%
data.groupby(["dim_feedforward", "num_layers"])\
.training_minutes\
.max().unstack().round(4)\
.style.background_gradient(axis = None)
# Out:
# <style type="text/css">
# #T_749e1_row0_col0 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_749e1_row0_col1 {
#   background-color: #ede8f3;
#   color: #000000;
# }
# #T_749e1_row0_col2 {
#   background-color: #d4d4e8;
#   color: #000000;
# }
# #T_749e1_row1_col0 {
#   background-color: #a9bfdc;
#   color: #000000;
# }
# #T_749e1_row1_col1, #T_749e1_row3_col2, #T_749e1_row8_col2 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_749e1_row1_col2 {
#   background-color: #034b76;
#   color: #f1f1f1;
# }
# #T_749e1_row2_col0 {
#   background-color: #a5bddb;
#   color: #000000;
# }
# #T_749e1_row2_col1 {
#   background-color: #2786bb;
#   color: #f1f1f1;
# }
# #T_749e1_row2_col2 {
#   background-color: #d8d7e9;
#   color: #000000;
# }
# #T_749e1_row3_col0 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_749e1_row3_col1 {
#   background-color: #e9e5f1;
#   color: #000000;
# }
# #T_749e1_row4_col0, #T_749e1_row5_col0 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_749e1_row4_col1 {
#   background-color: #1e80b8;
#   color: #f1f1f1;
# }
# #T_749e1_row4_col2 {
#   background-color: #cdd0e5;
#   color: #000000;
# }
# #T_749e1_row5_col1 {
#   background-color: #197db7;
#   color: #f1f1f1;
# }
# #T_749e1_row5_col2 {
#   background-color: #d3d4e7;
#   color: #000000;
# }
# #T_749e1_row6_col0 {
#   background-color: #faf3f9;
#   color: #000000;
# }
# #T_749e1_row6_col1 {
#   background-color: #167bb6;
#   color: #f1f1f1;
# }
# #T_749e1_row6_col2 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_749e1_row7_col0 {
#   background-color: #9ab8d8;
#   color: #000000;
# }
# #T_749e1_row7_col1 {
#   background-color: #1379b5;
#   color: #f1f1f1;
# }
# #T_749e1_row7_col2 {
#   background-color: #d0d1e6;
#   color: #000000;
# }
# #T_749e1_row8_col0 {
#   background-color: #96b6d7;
#   color: #000000;
# }
# #T_749e1_row8_col1 {
#   background-color: #e8e4f0;
#   color: #000000;
# }
# </style>
# <table id="T_749e1">
#   <thead>
#     <tr>
#       <th class="index_name level0" >num_layers</th>
#       <th id="T_749e1_level0_col0" class="col_heading level0 col0" >2</th>
#       <th id="T_749e1_level0_col1" class="col_heading level0 col1" >3</th>
#       <th id="T_749e1_level0_col2" class="col_heading level0 col2" >4</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >dim_feedforward</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_749e1_level0_row0" class="row_heading level0 row0" >100</th>
#       <td id="T_749e1_row0_col0" class="data row0 col0" >441.307600</td>
#       <td id="T_749e1_row0_col1" class="data row0 col1" >679.813300</td>
#       <td id="T_749e1_row0_col2" class="data row0 col2" >899.463900</td>
#     </tr>
#     <tr>
#       <th id="T_749e1_level0_row1" class="row_heading level0 row1" >150</th>
#       <td id="T_749e1_row1_col0" class="data row1 col0" >1162.284700</td>
#       <td id="T_749e1_row1_col1" class="data row1 col1" >nan</td>
#       <td id="T_749e1_row1_col2" class="data row1 col2" >2277.173700</td>
#     </tr>
#     <tr>
#       <th id="T_749e1_level0_row2" class="row_heading level0 row2" >200</th>
#       <td id="T_749e1_row2_col0" class="data row2 col0" >1185.520700</td>
#       <td id="T_749e1_row2_col1" class="data row2 col1" >1747.669900</td>
#       <td id="T_749e1_row2_col2" class="data row2 col2" >872.169000</td>
#     </tr>
#     <tr>
#       <th id="T_749e1_level0_row3" class="row_heading level0 row3" >250</th>
#       <td id="T_749e1_row3_col0" class="data row3 col0" >452.085100</td>
#       <td id="T_749e1_row3_col1" class="data row3 col1" >718.858300</td>
#       <td id="T_749e1_row3_col2" class="data row3 col2" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_749e1_level0_row4" class="row_heading level0 row4" >300</th>
#       <td id="T_749e1_row4_col0" class="data row4 col0" >465.847700</td>
#       <td id="T_749e1_row4_col1" class="data row4 col1" >1795.160000</td>
#       <td id="T_749e1_row4_col2" class="data row4 col2" >951.867800</td>
#     </tr>
#     <tr>
#       <th id="T_749e1_level0_row5" class="row_heading level0 row5" >350</th>
#       <td id="T_749e1_row5_col0" class="data row5 col0" >468.689100</td>
#       <td id="T_749e1_row5_col1" class="data row5 col1" >1815.022300</td>
#       <td id="T_749e1_row5_col2" class="data row5 col2" >911.784800</td>
#     </tr>
#     <tr>
#       <th id="T_749e1_level0_row6" class="row_heading level0 row6" >400</th>
#       <td id="T_749e1_row6_col0" class="data row6 col0" >504.642500</td>
#       <td id="T_749e1_row6_col1" class="data row6 col1" >1834.210800</td>
#       <td id="T_749e1_row6_col2" class="data row6 col2" >2416.676300</td>
#     </tr>
#     <tr>
#       <th id="T_749e1_level0_row7" class="row_heading level0 row7" >450</th>
#       <td id="T_749e1_row7_col0" class="data row7 col0" >1243.705100</td>
#       <td id="T_749e1_row7_col1" class="data row7 col1" >1850.731300</td>
#       <td id="T_749e1_row7_col2" class="data row7 col2" >941.956100</td>
#     </tr>
#     <tr>
#       <th id="T_749e1_level0_row8" class="row_heading level0 row8" >500</th>
#       <td id="T_749e1_row8_col0" class="data row8 col0" >1260.069200</td>
#       <td id="T_749e1_row8_col1" class="data row8 col1" >721.554100</td>
#       <td id="T_749e1_row8_col2" class="data row8 col2" >nan</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # queries

# %%
data.query('name == "13932680_10.pkl"')
# Out:
#       epoch  total_epochs  train_loss  dim_feedforward  attention_heads  \
# 0         1          2000    0.092456              250                4
# 1         2          2000    0.085470              250                4
# 2         3          2000    0.084494              250                4
# 3         4          2000    0.084123              250                4
# 4         5          2000    0.083889              250                4
# ...     ...           ...         ...              ...              ...
# 1995   1996          2000    0.001845              250                4
# 1996   1997          2000    0.001922              250                4
# 1997   1998          2000    0.001852              250                4
# 1998   1999          2000    0.001873              250                4
# 1999   2000          2000    0.001910              250                4
#
#       num_layers  weight_decay embeddings  dev_average_precision  dev_roc_auc  \
# 0              3           0.0      sbert               0.127296     0.649823
# 1              3           0.0      sbert               0.127296     0.649823
# 2              3           0.0      sbert               0.127296     0.649823
# 3              3           0.0      sbert               0.127296     0.649823
# 4              3           0.0      sbert               0.127296     0.649823
# ...          ...           ...        ...                    ...          ...
# 1995           3           0.0      sbert               0.127296     0.649823
# 1996           3           0.0      sbert               0.127296     0.649823
# 1997           3           0.0      sbert               0.127296     0.649823
# 1998           3           0.0      sbert               0.127296     0.649823
# 1999           3           0.0      sbert               0.127296     0.649823
#
#       training_minutes             name
# 0           718.858293  13932680_10.pkl
# 1           718.858293  13932680_10.pkl
# 2           718.858293  13932680_10.pkl
# 3           718.858293  13932680_10.pkl
# 4           718.858293  13932680_10.pkl
# ...                ...              ...
# 1995        718.858293  13932680_10.pkl
# 1996        718.858293  13932680_10.pkl
# 1997        718.858293  13932680_10.pkl
# 1998        718.858293  13932680_10.pkl
# 1999        718.858293  13932680_10.pkl
#
# [2000 rows x 12 columns]

# %%
data.query('name == "14158104_4.pkl"')
# Out:
#       epoch  total_epochs  train_loss  dim_feedforward  attention_heads  \
# 0         1          2000    0.085593              350                4
# 1         2          2000    0.082101              350                4
# 2         3          2000    0.080849              350                4
# 3         4          2000    0.079542              350                4
# 4         5          2000    0.078087              350                4
# ...     ...           ...         ...              ...              ...
# 1995   1996          2000    0.005928              350                4
# 1996   1997          2000    0.005845              350                4
# 1997   1998          2000    0.005776              350                4
# 1998   1999          2000    0.005838              350                4
# 1999   2000          2000    0.005927              350                4
#
#       num_layers  weight_decay embeddings  dev_average_precision  dev_roc_auc  \
# 0              3       0.00001    specter               0.122862     0.677173
# 1              3       0.00001    specter               0.122862     0.677173
# 2              3       0.00001    specter               0.122862     0.677173
# 3              3       0.00001    specter               0.122862     0.677173
# 4              3       0.00001    specter               0.122862     0.677173
# ...          ...           ...        ...                    ...          ...
# 1995           3       0.00001    specter               0.122862     0.677173
# 1996           3       0.00001    specter               0.122862     0.677173
# 1997           3       0.00001    specter               0.122862     0.677173
# 1998           3       0.00001    specter               0.122862     0.677173
# 1999           3       0.00001    specter               0.122862     0.677173
#
#       training_minutes            name
# 0          1815.022334  14158104_4.pkl
# 1          1815.022334  14158104_4.pkl
# 2          1815.022334  14158104_4.pkl
# 3          1815.022334  14158104_4.pkl
# 4          1815.022334  14158104_4.pkl
# ...                ...             ...
# 1995       1815.022334  14158104_4.pkl
# 1996       1815.022334  14158104_4.pkl
# 1997       1815.022334  14158104_4.pkl
# 1998       1815.022334  14158104_4.pkl
# 1999       1815.022334  14158104_4.pkl
#
# [2000 rows x 12 columns]

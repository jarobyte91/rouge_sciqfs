# %%
import pandas as pd
import os
from tqdm.notebook import tqdm 
from malnis import show
import matplotlib.pyplot as plt
# plt.style.use('seaborn-whitegrid')
import seaborn as sns
sns.set(style = "whitegrid")

# %%
specter_folder = "/home/jarobyte/scratch/malnis_dataset/lstm/specter/train_logs/"
specter_files = sorted(os.listdir(specter_folder))
specter_files
# Out:
# ['13922355_1.pkl',
#  '13922355_2.pkl',
#  '13922437_1.pkl',
#  '13922437_10.pkl',
#  '13922437_11.pkl',
#  '13922437_12.pkl',
#  '13922437_2.pkl',
#  '13922437_3.pkl',
#  '13922437_4.pkl',
#  '13922437_5.pkl',
#  '13922437_6.pkl',
#  '13922437_7.pkl',
#  '13922437_8.pkl',
#  '13922437_9.pkl',
#  '13925660_1.pkl',
#  '13925660_2.pkl',
#  '13925871_1.pkl',
#  '13925871_2.pkl',
#  '13925873_1.pkl',
#  '13925873_10.pkl',
#  '13925873_11.pkl',
#  '13925873_12.pkl',
#  '13925873_2.pkl',
#  '13925873_3.pkl',
#  '13925873_4.pkl',
#  '13925873_5.pkl',
#  '13925873_6.pkl',
#  '13925873_7.pkl',
#  '13925873_8.pkl',
#  '13925873_9.pkl',
#  '13954786_1.pkl',
#  '13954786_10.pkl',
#  '13954786_11.pkl',
#  '13954786_12.pkl',
#  '13954786_2.pkl',
#  '13954786_3.pkl',
#  '13954786_4.pkl',
#  '13954786_5.pkl',
#  '13954786_6.pkl',
#  '13954786_7.pkl',
#  '13954786_8.pkl',
#  '13954786_9.pkl']

# %%
specter_data = pd.concat([pd.read_pickle(specter_folder + x).assign(name = x) for x in tqdm(specter_files)])
show(specter_data)
# Out:
#   0%|          | 0/42 [00:00<?, ?it/s]
# (72060, 11)
#    epoch  total_epochs  train_loss  hidden_size  num_layers  weight_decay  \
# 0      1            10    0.119364          100           2           0.0
# 1      2            10    0.084868          100           2           0.0
# 2      3            10    0.083398          100           2           0.0
# 3      4            10    0.082685          100           2           0.0
# 4      5            10    0.082157          100           2           0.0
#
#   embeddings  dev_average_precision  dev_roc_auc  training_minutes  \
# 0    specter               0.081068      0.71104          0.410247
# 1    specter               0.081068      0.71104          0.410247
# 2    specter               0.081068      0.71104          0.410247
# 3    specter               0.081068      0.71104          0.410247
# 4    specter               0.081068      0.71104          0.410247
#
#              name
# 0  13922355_1.pkl
# 1  13922355_1.pkl
# 2  13922355_1.pkl
# 3  13922355_1.pkl
# 4  13922355_1.pkl

# %%
sbert_folder = "/home/jarobyte/scratch/malnis_dataset/lstm/sbert/train_logs/"
sbert_files = sorted(os.listdir(sbert_folder))
sbert_files
# Out:
# ['13930814_1.pkl',
#  '13930814_2.pkl',
#  '13932670_1.pkl',
#  '13932670_10.pkl',
#  '13932670_11.pkl',
#  '13932670_12.pkl',
#  '13932670_2.pkl',
#  '13932670_3.pkl',
#  '13932670_4.pkl',
#  '13932670_5.pkl',
#  '13932670_6.pkl',
#  '13932670_7.pkl',
#  '13932670_8.pkl',
#  '13932670_9.pkl',
#  '13954785_1.pkl',
#  '13954785_10.pkl',
#  '13954785_11.pkl',
#  '13954785_12.pkl',
#  '13954785_2.pkl',
#  '13954785_3.pkl',
#  '13954785_4.pkl',
#  '13954785_5.pkl',
#  '13954785_6.pkl',
#  '13954785_7.pkl',
#  '13954785_8.pkl',
#  '13954785_9.pkl',
#  'test.pkl']

# %%
sbert_data = pd.concat([pd.read_pickle(sbert_folder + x).assign(name = x) for x in tqdm(sbert_files)])
show(sbert_data)
# Out:
#   0%|          | 0/27 [00:00<?, ?it/s]
# (48030, 11)
#    epoch  total_epochs  train_loss  hidden_size  num_layers  weight_decay  \
# 0      1            10    0.136464          100           2           0.0
# 1      2            10    0.088155          100           2           0.0
# 2      3            10    0.086113          100           2           0.0
# 3      4            10    0.084596          100           2           0.0
# 4      5            10    0.084002          100           2           0.0
#
#   embeddings  dev_average_precision  dev_roc_auc  training_minutes  \
# 0      sbert               0.063248     0.668785          0.410197
# 1      sbert               0.063248     0.668785          0.410197
# 2      sbert               0.063248     0.668785          0.410197
# 3      sbert               0.063248     0.668785          0.410197
# 4      sbert               0.063248     0.668785          0.410197
#
#              name
# 0  13930814_1.pkl
# 1  13930814_1.pkl
# 2  13930814_1.pkl
# 3  13930814_1.pkl
# 4  13930814_1.pkl

# %%
data = pd.concat([specter_data, sbert_data])
show(data)
# Out:
# (120090, 11)
#    epoch  total_epochs  train_loss  hidden_size  num_layers  weight_decay  \
# 0      1            10    0.119364          100           2           0.0
# 1      2            10    0.084868          100           2           0.0
# 2      3            10    0.083398          100           2           0.0
# 3      4            10    0.082685          100           2           0.0
# 4      5            10    0.082157          100           2           0.0
#
#   embeddings  dev_average_precision  dev_roc_auc  training_minutes  \
# 0    specter               0.081068      0.71104          0.410247
# 1    specter               0.081068      0.71104          0.410247
# 2    specter               0.081068      0.71104          0.410247
# 3    specter               0.081068      0.71104          0.410247
# 4    specter               0.081068      0.71104          0.410247
#
#              name
# 0  13922355_1.pkl
# 1  13922355_1.pkl
# 2  13922355_1.pkl
# 3  13922355_1.pkl
# 4  13922355_1.pkl

# %% [markdown]
# # basic stats

# %%
data.total_epochs.max()
# Out:
# 2000

# %%
# max training hours

data.groupby("embeddings").training_minutes.max() / 60
# Out:
# embeddings
# sbert      4.819626
# specter    5.683935
# Name: training_minutes, dtype: float64

# %%
data.groupby("name").embeddings.min().value_counts()
# Out:
# specter    42
# sbert      27
# Name: embeddings, dtype: int64

# %%
data.groupby("name").weight_decay.min().value_counts()
# Out:
# 0.00000    45
# 0.00001    10
# 0.00010     8
# 0.00100     5
# 0.01000     1
# Name: weight_decay, dtype: int64

# %%
data.groupby("name").min().groupby(["weight_decay", "embeddings"]).size().unstack()
# Out:
# embeddings    sbert  specter
# weight_decay
# 0.00000        15.0     30.0
# 0.00001         4.0      6.0
# 0.00010         5.0      3.0
# 0.00100         3.0      2.0
# 0.01000         NaN      1.0

# %%
# best training loss

data.groupby("name").train_loss.min().sort_values().head()
# Out:
# name
# 13932670_9.pkl     0.000167
# 13922437_11.pkl    0.000168
# 13925873_10.pkl    0.000175
# 13925873_2.pkl     0.000186
# 13925873_11.pkl    0.000190
# Name: train_loss, dtype: float64

# %%
# best roc auc

data.groupby("name").dev_roc_auc.mean().sort_values(ascending = False).head()
# Out:
# name
# 13954786_8.pkl     0.730819
# 13954786_11.pkl    0.730342
# 13954786_4.pkl     0.728160
# 13932670_11.pkl    0.724699
# 13954785_10.pkl    0.724204
# Name: dev_roc_auc, dtype: float64

# %%
# best average precision

data.groupby("name").dev_average_precision.max().sort_values(ascending = False).head()
# Out:
# name
# 13925873_9.pkl     0.178800
# 13922437_5.pkl     0.178683
# 13925873_10.pkl    0.176986
# 13922437_11.pkl    0.176810
# 13925873_11.pkl    0.171324
# Name: dev_average_precision, dtype: float64

# %%
# best models by category

data.groupby("name").min()[["embeddings", "train_loss", "dev_average_precision", "dev_roc_auc"]]\
.sort_values(["embeddings", "dev_average_precision"], ascending = False)\
.groupby("embeddings").head(3)
# Out:
#                 embeddings  train_loss  dev_average_precision  dev_roc_auc
# name
# 13925873_9.pkl     specter    0.000193               0.178800     0.706836
# 13922437_5.pkl     specter    0.000235               0.178683     0.684599
# 13925873_10.pkl    specter    0.000175               0.176986     0.707889
# 13932670_9.pkl       sbert    0.000167               0.131889     0.701244
# 13932670_11.pkl      sbert    0.000464               0.130849     0.724699
# 13932670_1.pkl       sbert    0.000200               0.129196     0.700064

# %% [markdown]
# # the effect of weight decay

# %%
data.groupby("weight_decay").train_loss.min()
# Out:
# weight_decay
# 0.00000    0.000167
# 0.00001    0.023780
# 0.00010    0.073019
# 0.00100    0.083366
# 0.01000    0.098115
# Name: train_loss, dtype: float64

# %%
data.groupby("weight_decay").dev_roc_auc.max()
# Out:
# weight_decay
# 0.00000    0.724699
# 0.00001    0.724204
# 0.00010    0.730819
# 0.00100    0.692669
# 0.01000    0.616161
# Name: dev_roc_auc, dtype: float64

# %%
data.groupby("weight_decay").dev_average_precision.max()
# Out:
# weight_decay
# 0.00000    0.178800
# 0.00001    0.090281
# 0.00010    0.094672
# 0.00100    0.073141
# 0.01000    0.050772
# Name: dev_average_precision, dtype: float64

# %% [markdown]
# # embeddings

# %%
sns.boxplot(
    data = data.groupby("name")[["dev_roc_auc", "embeddings"]].min(),
    x = "embeddings", 
    y = "dev_roc_auc"
)
# plt.ylim(0)
plt.xlabel("Embeddings", fontsize = "large")
plt.ylabel("ROC AUC", fontsize = "large")
plt.show()

# %%
sns.boxplot(
    data = data.groupby("name")[["dev_average_precision", "embeddings"]].min(),
    x = "embeddings", 
    y = "dev_average_precision"
)
# plt.ylim(0)
plt.xlabel("Embeddings", fontsize = "large")
plt.ylabel("Average Precision", fontsize = "large")
plt.show()

# %%
data.groupby("name")[["embeddings", "dev_average_precision"]].max()\
.groupby("embeddings").dev_average_precision.describe().T
# Out:
# embeddings      sbert    specter
# count       27.000000  42.000000
# mean         0.086669   0.120976
# std          0.027647   0.038885
# min          0.043570   0.050772
# 25%          0.065480   0.084048
# 50%          0.085477   0.123191
# 75%          0.106438   0.152560
# max          0.131889   0.178800

# %% [markdown]
# # metrics

# %%
data.groupby(["hidden_size", "num_layers"])\
.train_loss\
.min().unstack()\
.style.background_gradient(axis = None)
# Out:
# <style type="text/css">
# #T_fc0b1_row0_col0, #T_fc0b1_row1_col0, #T_fc0b1_row1_col2, #T_fc0b1_row2_col1, #T_fc0b1_row2_col2, #T_fc0b1_row2_col3, #T_fc0b1_row3_col0, #T_fc0b1_row3_col2, #T_fc0b1_row4_col1, #T_fc0b1_row4_col2, #T_fc0b1_row4_col3, #T_fc0b1_row5_col0, #T_fc0b1_row5_col3, #T_fc0b1_row6_col0, #T_fc0b1_row6_col2, #T_fc0b1_row6_col3, #T_fc0b1_row7_col0, #T_fc0b1_row7_col1, #T_fc0b1_row7_col2, #T_fc0b1_row8_col0, #T_fc0b1_row8_col2 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_fc0b1_row0_col1, #T_fc0b1_row4_col0 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_fc0b1_row0_col2 {
#   background-color: #ede7f2;
#   color: #000000;
# }
# #T_fc0b1_row0_col3 {
#   background-color: #4897c4;
#   color: #f1f1f1;
# }
# #T_fc0b1_row1_col1 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_fc0b1_row1_col3 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_fc0b1_row2_col0, #T_fc0b1_row3_col1, #T_fc0b1_row3_col3, #T_fc0b1_row5_col1, #T_fc0b1_row5_col2, #T_fc0b1_row6_col1, #T_fc0b1_row7_col3 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_fc0b1_row8_col1 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_fc0b1_row8_col3 {
#   background-color: #b9c6e0;
#   color: #000000;
# }
# </style>
# <table id="T_fc0b1">
#   <thead>
#     <tr>
#       <th class="index_name level0" >num_layers</th>
#       <th id="T_fc0b1_level0_col0" class="col_heading level0 col0" >1</th>
#       <th id="T_fc0b1_level0_col1" class="col_heading level0 col1" >2</th>
#       <th id="T_fc0b1_level0_col2" class="col_heading level0 col2" >3</th>
#       <th id="T_fc0b1_level0_col3" class="col_heading level0 col3" >4</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >hidden_size</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fc0b1_level0_row0" class="row_heading level0 row0" >100</th>
#       <td id="T_fc0b1_row0_col0" class="data row0 col0" >0.000375</td>
#       <td id="T_fc0b1_row0_col1" class="data row0 col1" >0.000478</td>
#       <td id="T_fc0b1_row0_col2" class="data row0 col2" >0.009367</td>
#       <td id="T_fc0b1_row0_col3" class="data row0 col3" >0.043709</td>
#     </tr>
#     <tr>
#       <th id="T_fc0b1_level0_row1" class="row_heading level0 row1" >150</th>
#       <td id="T_fc0b1_row1_col0" class="data row1 col0" >0.000287</td>
#       <td id="T_fc0b1_row1_col1" class="data row1 col1" >0.000925</td>
#       <td id="T_fc0b1_row1_col2" class="data row1 col2" >0.000294</td>
#       <td id="T_fc0b1_row1_col3" class="data row1 col3" >0.001299</td>
#     </tr>
#     <tr>
#       <th id="T_fc0b1_level0_row2" class="row_heading level0 row2" >200</th>
#       <td id="T_fc0b1_row2_col0" class="data row2 col0" >nan</td>
#       <td id="T_fc0b1_row2_col1" class="data row2 col1" >0.000232</td>
#       <td id="T_fc0b1_row2_col2" class="data row2 col2" >0.000186</td>
#       <td id="T_fc0b1_row2_col3" class="data row2 col3" >0.000298</td>
#     </tr>
#     <tr>
#       <th id="T_fc0b1_level0_row3" class="row_heading level0 row3" >250</th>
#       <td id="T_fc0b1_row3_col0" class="data row3 col0" >0.000207</td>
#       <td id="T_fc0b1_row3_col1" class="data row3 col1" >nan</td>
#       <td id="T_fc0b1_row3_col2" class="data row3 col2" >0.000264</td>
#       <td id="T_fc0b1_row3_col3" class="data row3 col3" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_fc0b1_level0_row4" class="row_heading level0 row4" >300</th>
#       <td id="T_fc0b1_row4_col0" class="data row4 col0" >0.000551</td>
#       <td id="T_fc0b1_row4_col1" class="data row4 col1" >0.000318</td>
#       <td id="T_fc0b1_row4_col2" class="data row4 col2" >0.000271</td>
#       <td id="T_fc0b1_row4_col3" class="data row4 col3" >0.000263</td>
#     </tr>
#     <tr>
#       <th id="T_fc0b1_level0_row5" class="row_heading level0 row5" >350</th>
#       <td id="T_fc0b1_row5_col0" class="data row5 col0" >0.000190</td>
#       <td id="T_fc0b1_row5_col1" class="data row5 col1" >nan</td>
#       <td id="T_fc0b1_row5_col2" class="data row5 col2" >nan</td>
#       <td id="T_fc0b1_row5_col3" class="data row5 col3" >0.000240</td>
#     </tr>
#     <tr>
#       <th id="T_fc0b1_level0_row6" class="row_heading level0 row6" >400</th>
#       <td id="T_fc0b1_row6_col0" class="data row6 col0" >0.000192</td>
#       <td id="T_fc0b1_row6_col1" class="data row6 col1" >nan</td>
#       <td id="T_fc0b1_row6_col2" class="data row6 col2" >0.000221</td>
#       <td id="T_fc0b1_row6_col3" class="data row6 col3" >0.000235</td>
#     </tr>
#     <tr>
#       <th id="T_fc0b1_level0_row7" class="row_heading level0 row7" >450</th>
#       <td id="T_fc0b1_row7_col0" class="data row7 col0" >0.000175</td>
#       <td id="T_fc0b1_row7_col1" class="data row7 col1" >0.000208</td>
#       <td id="T_fc0b1_row7_col2" class="data row7 col2" >0.000200</td>
#       <td id="T_fc0b1_row7_col3" class="data row7 col3" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_fc0b1_level0_row8" class="row_heading level0 row8" >500</th>
#       <td id="T_fc0b1_row8_col0" class="data row8 col0" >0.000168</td>
#       <td id="T_fc0b1_row8_col1" class="data row8 col1" >0.074270</td>
#       <td id="T_fc0b1_row8_col2" class="data row8 col2" >0.000167</td>
#       <td id="T_fc0b1_row8_col3" class="data row8 col3" >0.023780</td>
#     </tr>
#   </tbody>
# </table>

# %%
data.groupby(["hidden_size", "num_layers"])\
.dev_roc_auc\
.max().unstack().round(4)\
.style.background_gradient(axis = None)
# Out:
# <style type="text/css">
# #T_4266c_row0_col0 {
#   background-color: #4897c4;
#   color: #f1f1f1;
# }
# #T_4266c_row0_col1 {
#   background-color: #046198;
#   color: #f1f1f1;
# }
# #T_4266c_row0_col2, #T_4266c_row3_col2 {
#   background-color: #7bacd1;
#   color: #f1f1f1;
# }
# #T_4266c_row0_col3 {
#   background-color: #348ebf;
#   color: #f1f1f1;
# }
# #T_4266c_row1_col0 {
#   background-color: #04639b;
#   color: #f1f1f1;
# }
# #T_4266c_row1_col1 {
#   background-color: #045e93;
#   color: #f1f1f1;
# }
# #T_4266c_row1_col2, #T_4266c_row4_col0 {
#   background-color: #045483;
#   color: #f1f1f1;
# }
# #T_4266c_row1_col3 {
#   background-color: #3d93c2;
#   color: #f1f1f1;
# }
# #T_4266c_row2_col0, #T_4266c_row3_col1, #T_4266c_row3_col3, #T_4266c_row5_col1, #T_4266c_row5_col2, #T_4266c_row6_col1, #T_4266c_row7_col3 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_4266c_row2_col1 {
#   background-color: #1379b5;
#   color: #f1f1f1;
# }
# #T_4266c_row2_col2 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_4266c_row2_col3 {
#   background-color: #62a2cb;
#   color: #f1f1f1;
# }
# #T_4266c_row3_col0 {
#   background-color: #187cb6;
#   color: #f1f1f1;
# }
# #T_4266c_row4_col1 {
#   background-color: #2383ba;
#   color: #f1f1f1;
# }
# #T_4266c_row4_col2 {
#   background-color: #02395a;
#   color: #f1f1f1;
# }
# #T_4266c_row4_col3 {
#   background-color: #a8bedc;
#   color: #000000;
# }
# #T_4266c_row5_col0 {
#   background-color: #0f76b3;
#   color: #f1f1f1;
# }
# #T_4266c_row5_col3 {
#   background-color: #a5bddb;
#   color: #000000;
# }
# #T_4266c_row6_col0 {
#   background-color: #0771b1;
#   color: #f1f1f1;
# }
# #T_4266c_row6_col2 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_4266c_row6_col3 {
#   background-color: #034a74;
#   color: #f1f1f1;
# }
# #T_4266c_row7_col0 {
#   background-color: #034973;
#   color: #f1f1f1;
# }
# #T_4266c_row7_col1 {
#   background-color: #4295c3;
#   color: #f1f1f1;
# }
# #T_4266c_row7_col2 {
#   background-color: #197db7;
#   color: #f1f1f1;
# }
# #T_4266c_row8_col0 {
#   background-color: #046299;
#   color: #f1f1f1;
# }
# #T_4266c_row8_col1 {
#   background-color: #023f64;
#   color: #f1f1f1;
# }
# #T_4266c_row8_col2 {
#   background-color: #1e80b8;
#   color: #f1f1f1;
# }
# #T_4266c_row8_col3 {
#   background-color: #ced0e6;
#   color: #000000;
# }
# </style>
# <table id="T_4266c">
#   <thead>
#     <tr>
#       <th class="index_name level0" >num_layers</th>
#       <th id="T_4266c_level0_col0" class="col_heading level0 col0" >1</th>
#       <th id="T_4266c_level0_col1" class="col_heading level0 col1" >2</th>
#       <th id="T_4266c_level0_col2" class="col_heading level0 col2" >3</th>
#       <th id="T_4266c_level0_col3" class="col_heading level0 col3" >4</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >hidden_size</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4266c_level0_row0" class="row_heading level0 row0" >100</th>
#       <td id="T_4266c_row0_col0" class="data row0 col0" >0.691900</td>
#       <td id="T_4266c_row0_col1" class="data row0 col1" >0.715100</td>
#       <td id="T_4266c_row0_col2" class="data row0 col2" >0.681800</td>
#       <td id="T_4266c_row0_col3" class="data row0 col3" >0.695700</td>
#     </tr>
#     <tr>
#       <th id="T_4266c_level0_row1" class="row_heading level0 row1" >150</th>
#       <td id="T_4266c_row1_col0" class="data row1 col0" >0.714100</td>
#       <td id="T_4266c_row1_col1" class="data row1 col1" >0.717000</td>
#       <td id="T_4266c_row1_col2" class="data row1 col2" >0.721100</td>
#       <td id="T_4266c_row1_col3" class="data row1 col3" >0.694000</td>
#     </tr>
#     <tr>
#       <th id="T_4266c_level0_row2" class="row_heading level0 row2" >200</th>
#       <td id="T_4266c_row2_col0" class="data row2 col0" >nan</td>
#       <td id="T_4266c_row2_col1" class="data row2 col1" >0.703700</td>
#       <td id="T_4266c_row2_col2" class="data row2 col2" >0.636200</td>
#       <td id="T_4266c_row2_col3" class="data row2 col3" >0.687000</td>
#     </tr>
#     <tr>
#       <th id="T_4266c_level0_row3" class="row_heading level0 row3" >250</th>
#       <td id="T_4266c_row3_col0" class="data row3 col0" >0.702600</td>
#       <td id="T_4266c_row3_col1" class="data row3 col1" >nan</td>
#       <td id="T_4266c_row3_col2" class="data row3 col2" >0.681700</td>
#       <td id="T_4266c_row3_col3" class="data row3 col3" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_4266c_level0_row4" class="row_heading level0 row4" >300</th>
#       <td id="T_4266c_row4_col0" class="data row4 col0" >0.721000</td>
#       <td id="T_4266c_row4_col1" class="data row4 col1" >0.700000</td>
#       <td id="T_4266c_row4_col2" class="data row4 col2" >0.730300</td>
#       <td id="T_4266c_row4_col3" class="data row4 col3" >0.671100</td>
#     </tr>
#     <tr>
#       <th id="T_4266c_level0_row5" class="row_heading level0 row5" >350</th>
#       <td id="T_4266c_row5_col0" class="data row5 col0" >0.704900</td>
#       <td id="T_4266c_row5_col1" class="data row5 col1" >nan</td>
#       <td id="T_4266c_row5_col2" class="data row5 col2" >nan</td>
#       <td id="T_4266c_row5_col3" class="data row5 col3" >0.672000</td>
#     </tr>
#     <tr>
#       <th id="T_4266c_level0_row6" class="row_heading level0 row6" >400</th>
#       <td id="T_4266c_row6_col0" class="data row6 col0" >0.706600</td>
#       <td id="T_4266c_row6_col1" class="data row6 col1" >nan</td>
#       <td id="T_4266c_row6_col2" class="data row6 col2" >0.730800</td>
#       <td id="T_4266c_row6_col3" class="data row6 col3" >0.724200</td>
#     </tr>
#     <tr>
#       <th id="T_4266c_level0_row7" class="row_heading level0 row7" >450</th>
#       <td id="T_4266c_row7_col0" class="data row7 col0" >0.724700</td>
#       <td id="T_4266c_row7_col1" class="data row7 col1" >0.692800</td>
#       <td id="T_4266c_row7_col2" class="data row7 col2" >0.702000</td>
#       <td id="T_4266c_row7_col3" class="data row7 col3" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_4266c_level0_row8" class="row_heading level0 row8" >500</th>
#       <td id="T_4266c_row8_col0" class="data row8 col0" >0.714600</td>
#       <td id="T_4266c_row8_col1" class="data row8 col1" >0.728200</td>
#       <td id="T_4266c_row8_col2" class="data row8 col2" >0.701200</td>
#       <td id="T_4266c_row8_col3" class="data row8 col3" >0.660500</td>
#     </tr>
#   </tbody>
# </table>

# %%
data.groupby(["hidden_size", "num_layers"])\
.dev_average_precision\
.max().unstack().round(4)\
.style.background_gradient(axis = None)
# Out:
# <style type="text/css">
# #T_921c2_row0_col0 {
#   background-color: #c8cde4;
#   color: #000000;
# }
# #T_921c2_row0_col1 {
#   background-color: #d1d2e6;
#   color: #000000;
# }
# #T_921c2_row0_col2 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_921c2_row0_col3 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_921c2_row1_col0 {
#   background-color: #88b1d4;
#   color: #000000;
# }
# #T_921c2_row1_col1 {
#   background-color: #f1ebf5;
#   color: #000000;
# }
# #T_921c2_row1_col2 {
#   background-color: #9cb9d9;
#   color: #000000;
# }
# #T_921c2_row1_col3 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_921c2_row2_col0, #T_921c2_row3_col1, #T_921c2_row3_col3, #T_921c2_row5_col1, #T_921c2_row5_col2, #T_921c2_row6_col1, #T_921c2_row7_col3 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_921c2_row2_col1 {
#   background-color: #509ac6;
#   color: #f1f1f1;
# }
# #T_921c2_row2_col2 {
#   background-color: #4897c4;
#   color: #f1f1f1;
# }
# #T_921c2_row2_col3 {
#   background-color: #2987bc;
#   color: #f1f1f1;
# }
# #T_921c2_row3_col0 {
#   background-color: #167bb6;
#   color: #f1f1f1;
# }
# #T_921c2_row3_col2 {
#   background-color: #3d93c2;
#   color: #f1f1f1;
# }
# #T_921c2_row4_col0 {
#   background-color: #99b8d8;
#   color: #000000;
# }
# #T_921c2_row4_col1 {
#   background-color: #ced0e6;
#   color: #000000;
# }
# #T_921c2_row4_col2 {
#   background-color: #308cbe;
#   color: #f1f1f1;
# }
# #T_921c2_row4_col3 {
#   background-color: #04639b;
#   color: #f1f1f1;
# }
# #T_921c2_row5_col0 {
#   background-color: #034c78;
#   color: #f1f1f1;
# }
# #T_921c2_row5_col3, #T_921c2_row6_col0 {
#   background-color: #034e7b;
#   color: #f1f1f1;
# }
# #T_921c2_row6_col2 {
#   background-color: #0c74b2;
#   color: #f1f1f1;
# }
# #T_921c2_row6_col3, #T_921c2_row8_col0 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_921c2_row7_col0 {
#   background-color: #023c5f;
#   color: #f1f1f1;
# }
# #T_921c2_row7_col1 {
#   background-color: #1278b4;
#   color: #f1f1f1;
# }
# #T_921c2_row7_col2 {
#   background-color: #78abd0;
#   color: #f1f1f1;
# }
# #T_921c2_row8_col1 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_921c2_row8_col2 {
#   background-color: #046299;
#   color: #f1f1f1;
# }
# #T_921c2_row8_col3 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# </style>
# <table id="T_921c2">
#   <thead>
#     <tr>
#       <th class="index_name level0" >num_layers</th>
#       <th id="T_921c2_level0_col0" class="col_heading level0 col0" >1</th>
#       <th id="T_921c2_level0_col1" class="col_heading level0 col1" >2</th>
#       <th id="T_921c2_level0_col2" class="col_heading level0 col2" >3</th>
#       <th id="T_921c2_level0_col3" class="col_heading level0 col3" >4</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >hidden_size</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_921c2_level0_row0" class="row_heading level0 row0" >100</th>
#       <td id="T_921c2_row0_col0" class="data row0 col0" >0.108600</td>
#       <td id="T_921c2_row0_col1" class="data row0 col1" >0.106000</td>
#       <td id="T_921c2_row0_col2" class="data row0 col2" >0.081800</td>
#       <td id="T_921c2_row0_col3" class="data row0 col3" >0.086700</td>
#     </tr>
#     <tr>
#       <th id="T_921c2_level0_row1" class="row_heading level0 row1" >150</th>
#       <td id="T_921c2_row1_col0" class="data row1 col0" >0.125700</td>
#       <td id="T_921c2_row1_col1" class="data row1 col1" >0.090700</td>
#       <td id="T_921c2_row1_col2" class="data row1 col2" >0.120700</td>
#       <td id="T_921c2_row1_col3" class="data row1 col3" >0.095900</td>
#     </tr>
#     <tr>
#       <th id="T_921c2_level0_row2" class="row_heading level0 row2" >200</th>
#       <td id="T_921c2_row2_col0" class="data row2 col0" >nan</td>
#       <td id="T_921c2_row2_col1" class="data row2 col1" >0.137200</td>
#       <td id="T_921c2_row2_col2" class="data row2 col2" >0.138900</td>
#       <td id="T_921c2_row2_col3" class="data row2 col3" >0.145700</td>
#     </tr>
#     <tr>
#       <th id="T_921c2_level0_row3" class="row_heading level0 row3" >250</th>
#       <td id="T_921c2_row3_col0" class="data row3 col0" >0.150200</td>
#       <td id="T_921c2_row3_col1" class="data row3 col1" >nan</td>
#       <td id="T_921c2_row3_col2" class="data row3 col2" >0.141000</td>
#       <td id="T_921c2_row3_col3" class="data row3 col3" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_921c2_level0_row4" class="row_heading level0 row4" >300</th>
#       <td id="T_921c2_row4_col0" class="data row4 col0" >0.121500</td>
#       <td id="T_921c2_row4_col1" class="data row4 col1" >0.106700</td>
#       <td id="T_921c2_row4_col2" class="data row4 col2" >0.143700</td>
#       <td id="T_921c2_row4_col3" class="data row4 col3" >0.161700</td>
#     </tr>
#     <tr>
#       <th id="T_921c2_level0_row5" class="row_heading level0 row5" >350</th>
#       <td id="T_921c2_row5_col0" class="data row5 col0" >0.171300</td>
#       <td id="T_921c2_row5_col1" class="data row5 col1" >nan</td>
#       <td id="T_921c2_row5_col2" class="data row5 col2" >nan</td>
#       <td id="T_921c2_row5_col3" class="data row5 col3" >0.170800</td>
#     </tr>
#     <tr>
#       <th id="T_921c2_level0_row6" class="row_heading level0 row6" >400</th>
#       <td id="T_921c2_row6_col0" class="data row6 col0" >0.170800</td>
#       <td id="T_921c2_row6_col1" class="data row6 col1" >nan</td>
#       <td id="T_921c2_row6_col2" class="data row6 col2" >0.152900</td>
#       <td id="T_921c2_row6_col3" class="data row6 col3" >0.178700</td>
#     </tr>
#     <tr>
#       <th id="T_921c2_level0_row7" class="row_heading level0 row7" >450</th>
#       <td id="T_921c2_row7_col0" class="data row7 col0" >0.177000</td>
#       <td id="T_921c2_row7_col1" class="data row7 col1" >0.151500</td>
#       <td id="T_921c2_row7_col2" class="data row7 col2" >0.129200</td>
#       <td id="T_921c2_row7_col3" class="data row7 col3" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_921c2_level0_row8" class="row_heading level0 row8" >500</th>
#       <td id="T_921c2_row8_col0" class="data row8 col0" >0.178800</td>
#       <td id="T_921c2_row8_col1" class="data row8 col1" >0.091500</td>
#       <td id="T_921c2_row8_col2" class="data row8 col2" >0.162300</td>
#       <td id="T_921c2_row8_col3" class="data row8 col3" >0.083900</td>
#     </tr>
#   </tbody>
# </table>

# %%
data.groupby(["hidden_size", "num_layers"])\
.training_minutes\
.max().unstack().round(4)\
.style.background_gradient(axis = None)
# Out:
# <style type="text/css">
# #T_db35a_row0_col0 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_db35a_row0_col1 {
#   background-color: #eee9f3;
#   color: #000000;
# }
# #T_db35a_row0_col2 {
#   background-color: #d9d8ea;
#   color: #000000;
# }
# #T_db35a_row0_col3 {
#   background-color: #bbc7e0;
#   color: #000000;
# }
# #T_db35a_row1_col0 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_db35a_row1_col1 {
#   background-color: #eee8f3;
#   color: #000000;
# }
# #T_db35a_row1_col2 {
#   background-color: #d5d5e8;
#   color: #000000;
# }
# #T_db35a_row1_col3, #T_db35a_row2_col3 {
#   background-color: #b4c4df;
#   color: #000000;
# }
# #T_db35a_row2_col0, #T_db35a_row3_col1, #T_db35a_row3_col3, #T_db35a_row5_col1, #T_db35a_row5_col2, #T_db35a_row6_col1, #T_db35a_row7_col3 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_db35a_row2_col1 {
#   background-color: #e9e5f1;
#   color: #000000;
# }
# #T_db35a_row2_col2 {
#   background-color: #ced0e6;
#   color: #000000;
# }
# #T_db35a_row3_col0 {
#   background-color: #f3edf5;
#   color: #000000;
# }
# #T_db35a_row3_col2 {
#   background-color: #9ebad9;
#   color: #000000;
# }
# #T_db35a_row4_col0 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_db35a_row4_col1 {
#   background-color: #e2dfee;
#   color: #000000;
# }
# #T_db35a_row4_col2 {
#   background-color: #a5bddb;
#   color: #000000;
# }
# #T_db35a_row4_col3 {
#   background-color: #69a5cc;
#   color: #f1f1f1;
# }
# #T_db35a_row5_col0 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_db35a_row5_col3 {
#   background-color: #045e94;
#   color: #f1f1f1;
# }
# #T_db35a_row6_col0 {
#   background-color: #eae6f1;
#   color: #000000;
# }
# #T_db35a_row6_col2 {
#   background-color: #6fa7ce;
#   color: #f1f1f1;
# }
# #T_db35a_row6_col3 {
#   background-color: #056fae;
#   color: #f1f1f1;
# }
# #T_db35a_row7_col0 {
#   background-color: #d4d4e8;
#   color: #000000;
# }
# #T_db35a_row7_col1 {
#   background-color: #63a2cb;
#   color: #f1f1f1;
# }
# #T_db35a_row7_col2 {
#   background-color: #04639b;
#   color: #f1f1f1;
# }
# #T_db35a_row8_col0 {
#   background-color: #dcdaeb;
#   color: #000000;
# }
# #T_db35a_row8_col1 {
#   background-color: #86b0d3;
#   color: #000000;
# }
# #T_db35a_row8_col2 {
#   background-color: #0570b0;
#   color: #f1f1f1;
# }
# #T_db35a_row8_col3 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_db35a">
#   <thead>
#     <tr>
#       <th class="index_name level0" >num_layers</th>
#       <th id="T_db35a_level0_col0" class="col_heading level0 col0" >1</th>
#       <th id="T_db35a_level0_col1" class="col_heading level0 col1" >2</th>
#       <th id="T_db35a_level0_col2" class="col_heading level0 col2" >3</th>
#       <th id="T_db35a_level0_col3" class="col_heading level0 col3" >4</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >hidden_size</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_db35a_level0_row0" class="row_heading level0 row0" >100</th>
#       <td id="T_db35a_row0_col0" class="data row0 col0" >49.533400</td>
#       <td id="T_db35a_row0_col1" class="data row0 col1" >82.402100</td>
#       <td id="T_db35a_row0_col2" class="data row0 col2" >110.529800</td>
#       <td id="T_db35a_row0_col3" class="data row0 col3" >140.980500</td>
#     </tr>
#     <tr>
#       <th id="T_db35a_level0_row1" class="row_heading level0 row1" >150</th>
#       <td id="T_db35a_row1_col0" class="data row1 col0" >56.005100</td>
#       <td id="T_db35a_row1_col1" class="data row1 col1" >83.547900</td>
#       <td id="T_db35a_row1_col2" class="data row1 col2" >116.078600</td>
#       <td id="T_db35a_row1_col3" class="data row1 col3" >147.239600</td>
#     </tr>
#     <tr>
#       <th id="T_db35a_level0_row2" class="row_heading level0 row2" >200</th>
#       <td id="T_db35a_row2_col0" class="data row2 col0" >nan</td>
#       <td id="T_db35a_row2_col1" class="data row2 col1" >90.401700</td>
#       <td id="T_db35a_row2_col2" class="data row2 col2" >124.134700</td>
#       <td id="T_db35a_row2_col3" class="data row2 col3" >146.612300</td>
#     </tr>
#     <tr>
#       <th id="T_db35a_level0_row3" class="row_heading level0 row3" >250</th>
#       <td id="T_db35a_row3_col0" class="data row3 col0" >73.249800</td>
#       <td id="T_db35a_row3_col1" class="data row3 col1" >nan</td>
#       <td id="T_db35a_row3_col2" class="data row3 col2" >164.594200</td>
#       <td id="T_db35a_row3_col3" class="data row3 col3" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_db35a_level0_row4" class="row_heading level0 row4" >300</th>
#       <td id="T_db35a_row4_col0" class="data row4 col0" >56.381700</td>
#       <td id="T_db35a_row4_col1" class="data row4 col1" >99.228600</td>
#       <td id="T_db35a_row4_col2" class="data row4 col2" >159.650300</td>
#       <td id="T_db35a_row4_col3" class="data row4 col3" >201.137600</td>
#     </tr>
#     <tr>
#       <th id="T_db35a_level0_row5" class="row_heading level0 row5" >350</th>
#       <td id="T_db35a_row5_col0" class="data row5 col0" >92.383900</td>
#       <td id="T_db35a_row5_col1" class="data row5 col1" >nan</td>
#       <td id="T_db35a_row5_col2" class="data row5 col2" >nan</td>
#       <td id="T_db35a_row5_col3" class="data row5 col3" >297.684000</td>
#     </tr>
#     <tr>
#       <th id="T_db35a_level0_row6" class="row_heading level0 row6" >400</th>
#       <td id="T_db35a_row6_col0" class="data row6 col0" >89.344100</td>
#       <td id="T_db35a_row6_col1" class="data row6 col1" >nan</td>
#       <td id="T_db35a_row6_col2" class="data row6 col2" >198.347000</td>
#       <td id="T_db35a_row6_col3" class="data row6 col3" >269.541000</td>
#     </tr>
#     <tr>
#       <th id="T_db35a_level0_row7" class="row_heading level0 row7" >450</th>
#       <td id="T_db35a_row7_col0" class="data row7 col0" >117.060400</td>
#       <td id="T_db35a_row7_col1" class="data row7 col1" >204.662600</td>
#       <td id="T_db35a_row7_col2" class="data row7 col2" >289.177600</td>
#       <td id="T_db35a_row7_col3" class="data row7 col3" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_db35a_level0_row8" class="row_heading level0 row8" >500</th>
#       <td id="T_db35a_row8_col0" class="data row8 col0" >107.055200</td>
#       <td id="T_db35a_row8_col1" class="data row8 col1" >182.755700</td>
#       <td id="T_db35a_row8_col2" class="data row8 col2" >267.214300</td>
#       <td id="T_db35a_row8_col3" class="data row8 col3" >341.036100</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # queries

# %%
data.query("name == '13932670_9.pkl'")
# Out:
#       epoch  total_epochs  train_loss  hidden_size  num_layers  weight_decay  \
# 0         1          2000    0.102439          500           3           0.0
# 1         2          2000    0.085866          500           3           0.0
# 2         3          2000    0.083252          500           3           0.0
# 3         4          2000    0.082750          500           3           0.0
# 4         5          2000    0.082523          500           3           0.0
# ...     ...           ...         ...          ...         ...           ...
# 1995   1996          2000    0.000228          500           3           0.0
# 1996   1997          2000    0.000272          500           3           0.0
# 1997   1998          2000    0.000406          500           3           0.0
# 1998   1999          2000    0.000273          500           3           0.0
# 1999   2000          2000    0.000317          500           3           0.0
#
#      embeddings  dev_average_precision  dev_roc_auc  training_minutes  \
# 0         sbert               0.131889     0.701244        236.165301
# 1         sbert               0.131889     0.701244        236.165301
# 2         sbert               0.131889     0.701244        236.165301
# 3         sbert               0.131889     0.701244        236.165301
# 4         sbert               0.131889     0.701244        236.165301
# ...         ...                    ...          ...               ...
# 1995      sbert               0.131889     0.701244        236.165301
# 1996      sbert               0.131889     0.701244        236.165301
# 1997      sbert               0.131889     0.701244        236.165301
# 1998      sbert               0.131889     0.701244        236.165301
# 1999      sbert               0.131889     0.701244        236.165301
#
#                 name
# 0     13932670_9.pkl
# 1     13932670_9.pkl
# 2     13932670_9.pkl
# 3     13932670_9.pkl
# 4     13932670_9.pkl
# ...              ...
# 1995  13932670_9.pkl
# 1996  13932670_9.pkl
# 1997  13932670_9.pkl
# 1998  13932670_9.pkl
# 1999  13932670_9.pkl
#
# [2000 rows x 11 columns]

# %%
data.query("name == '13925873_9.pkl'")
# Out:
#       epoch  total_epochs  train_loss  hidden_size  num_layers  weight_decay  \
# 0         1          2000    0.102882          500           1           0.0
# 1         2          2000    0.083567          500           1           0.0
# 2         3          2000    0.082768          500           1           0.0
# 3         4          2000    0.082293          500           1           0.0
# 4         5          2000    0.081797          500           1           0.0
# ...     ...           ...         ...          ...         ...           ...
# 1995   1996          2000    0.000276          500           1           0.0
# 1996   1997          2000    0.000228          500           1           0.0
# 1997   1998          2000    0.000239          500           1           0.0
# 1998   1999          2000    0.000259          500           1           0.0
# 1999   2000          2000    0.000257          500           1           0.0
#
#      embeddings  dev_average_precision  dev_roc_auc  training_minutes  \
# 0       specter                 0.1788     0.706836         102.39068
# 1       specter                 0.1788     0.706836         102.39068
# 2       specter                 0.1788     0.706836         102.39068
# 3       specter                 0.1788     0.706836         102.39068
# 4       specter                 0.1788     0.706836         102.39068
# ...         ...                    ...          ...               ...
# 1995    specter                 0.1788     0.706836         102.39068
# 1996    specter                 0.1788     0.706836         102.39068
# 1997    specter                 0.1788     0.706836         102.39068
# 1998    specter                 0.1788     0.706836         102.39068
# 1999    specter                 0.1788     0.706836         102.39068
#
#                 name
# 0     13925873_9.pkl
# 1     13925873_9.pkl
# 2     13925873_9.pkl
# 3     13925873_9.pkl
# 4     13925873_9.pkl
# ...              ...
# 1995  13925873_9.pkl
# 1996  13925873_9.pkl
# 1997  13925873_9.pkl
# 1998  13925873_9.pkl
# 1999  13925873_9.pkl
#
# [2000 rows x 11 columns]
